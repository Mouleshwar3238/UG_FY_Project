# %% [markdown]
# # Optimal Number of Hidden Layers for LSTM

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
import matplotlib.pyplot as plt

# %%
# Reading the dataset
dft1 = pd.read_csv('TripA04.csv')
dft2 = pd.read_csv('TripA06.csv')
dft3 = pd.read_csv('TripA08.csv')
dft4 = pd.read_csv('TripA12.csv')
dft5 = pd.read_csv('TripA16.csv')
dft6 = pd.read_csv('TripA20.csv')
dft7 = pd.read_csv('TripA24.csv')
dft8 = pd.read_csv('TripA28.csv')
dft9 = pd.read_csv('TripA32.csv')

dft10 = pd.read_csv('TripB01.csv')
dft11 = pd.read_csv('TripB03.csv')
dft12 = pd.read_csv('TripB10.csv')
dft13 = pd.read_csv('TripB15.csv')
dft14 = pd.read_csv('TripB20.csv')
dft15 = pd.read_csv('TripB23.csv')
dft16 = pd.read_csv('TripB25.csv')
dft17 = pd.read_csv('TripB27.csv')
dft18 = pd.read_csv('TripB30.csv')
dft19 = pd.read_csv('TripB33.csv')
dft20 = pd.read_csv('TripB38.csv')


dft21 = pd.read_csv('TripA02.csv')
dft22 = pd.read_csv('TripA03.csv')
dft23 = pd.read_csv('TripA07.csv')
dft24 = pd.read_csv('TripA15.csv')
dft25 = pd.read_csv('TripA21.csv')
dft26 = pd.read_csv('TripA25.csv')
dft27 = pd.read_csv('TripA27.csv')

dft28 = pd.read_csv('TripB05.csv')
dft29 = pd.read_csv('TripB07.csv')
dft30 = pd.read_csv('TripB13.csv')
dft31 = pd.read_csv('TripB16.csv')
dft32 = pd.read_csv('TripB22.csv')
dft33 = pd.read_csv('TripB28.csv')
dft34 = pd.read_csv('TripB31.csv')
dft35 = pd.read_csv('TripB37.csv')
df = pd.concat([dft1, dft2, dft3, dft4, dft5, dft6, dft7, dft8, dft9, dft10, dft11, dft12, dft13, dft14, dft15, dft16, dft17, dft18, dft19, 
                dft20, dft21, dft22, dft23, dft24, dft25, dft26, dft27, dft28, dft29, dft30, dft31, dft32, dft33, dft34, dft35], ignore_index=True)
df.shape
# Out:
# (538214, 102)

# %%
df.describe()
# Out:
#             Time [s]  Velocity [km/h]  Elevation [m]   Throttle [%]  \
# count  538214.000000    538214.000000  538214.000000  538214.000000
# mean      927.042681        48.204922     524.400663      30.368202
# std       671.750161        36.031693      41.051019      17.871018
# min         0.000000         0.000000     449.000000       0.000000
# 25%       385.300000        19.989925     484.000000      17.280000
# 50%       814.800000        44.570000     520.000000      35.130000
# 75%      1335.300000        71.580000     556.520000      43.780000
# max      3251.700000       152.000000     664.990000      99.630000
#
#        Motor Torque [Nm]  Longitudinal Acceleration [m/s^2]  \
# count      538214.000000                      538214.000000
# mean           11.335276                           0.003850
# std            36.659281                           0.664698
# min           -87.500000                          -9.030000
# 25%             0.000000                          -0.240000
# 50%             7.000000                          -0.010000
# 75%            23.500000                           0.220000
# max           249.500000                           4.460000
#
#        Regenerative Braking Signal   Battery Voltage [V]  Battery Current [A]  \
# count                 538214.000000        538214.000000        538214.000000
# mean                       0.058006           376.137015           -21.815535
# std                        0.233630            10.793452            43.691556
# min                        0.000000           301.800000          -402.280000
# 25%                        0.000000           369.820000           -33.640000
# 50%                        0.000000           378.930000           -12.670000
# 75%                        0.000000           384.066905            -2.600000
# max                        1.000000           394.660000           143.840000
#
#        Battery Temperature [C]  ...  Temperature Footweel Co-Driver [°C]  \
# count            496092.000000  ...                         18223.000000
# mean                 16.707009  ...                            23.509571
# std                   7.965289  ...                             4.190296
# min                  -1.000000  ...                             0.490000
# 25%                  10.000000  ...                            23.010000
# 50%                  18.000000  ...                            24.020000
# 75%                  25.000000  ...                            25.120000
# max                  32.000000  ...                            29.110000
#
#        Temperature Feetvent Co-Driver [°C]  Temperature Feetvent Driver [°C]  \
# count                         18223.000000                      18223.000000
# mean                             44.573138                         44.204625
# std                               7.899812                          8.072591
# min                              -0.740000                         -0.650000
# 25%                              43.310000                         42.640000
# 50%                              44.390000                         43.780000
# 75%                              45.820000                         45.405000
# max                              55.210000                         55.910000
#
#        Temperature Head Co-Driver [°C]  Temperature Head Driver [°C]  \
# count                     18223.000000                  18223.000000
# mean                         17.991491                     19.900232
# std                           3.958080                      3.915668
# min                           3.980000                      4.680000
# 25%                          18.595000                     20.390000
# 50%                          19.500000                     21.170000
# 75%                          19.860000                     21.700000
# max                          21.350000                     23.870000
#
#        Temperature Vent right [°C]   Temperature Vent central right [°C]  \
# count                  18223.000000                         18223.000000
# mean                      33.153629                            32.101083
# std                        6.962805                             7.177824
# min                        0.310000                             0.400000
# 25%                       33.020000                            32.870000
# 50%                       33.870000                            33.880000
# 75%                       35.220000                            35.050000
# max                       42.900000                            39.760000
#
#        Temperature Vent central left [°C]  Temperature Vent right [°C]  \
# count                        18223.000000                 18223.000000
# mean                            35.385577                    31.368940
# std                              8.173045                     6.866679
# min                              0.660000                     0.920000
# 25%                             35.090000                    31.300000
# 50%                             36.270000                    32.080000
# 75%                             38.280000                    33.730000
# max                             46.480000                    41.070000
#
#        Battery Temperature [�C]
# count              23899.000000
# mean                   3.714842
# std                    1.633322
# min                    1.000000
# 25%                    2.000000
# 50%                    4.000000
# 75%                    5.000000
# max                    6.000000
#
# [8 rows x 102 columns]

# %%
# Extracting input variables and target variable from the dataset
attr = ['Battery Voltage [V]','Battery Current [A]','Battery Temperature [C]','SoC [%]']
df = df[:].loc[:,attr]

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# Battery Voltage [V]            0
# Battery Current [A]            0
# Battery Temperature [C]    42122
# SoC [%]                     5811
# dtype: int64

# %%
df = df.fillna(method = 'bfill')
df.isna().sum()
# Out:
# C:\Users\moule\AppData\Local\Temp\ipykernel_3952\214754001.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = 'bfill')
# Battery Voltage [V]        0
# Battery Current [A]        0
# Battery Temperature [C]    0
# SoC [%]                    0
# dtype: int64

# %%
df = df.sort_values(by='SoC [%]', ascending=False)
df
# Out:
#         Battery Voltage [V]  Battery Current [A]  Battery Temperature [C]  \
# 35770                391.57                -8.96                     26.0
# 35782                390.97               -16.99                     26.0
# 35792                390.83               -17.85                     26.0
# 35791                390.82               -17.96                     26.0
# 35790                390.87               -17.66                     26.0
# ...                     ...                  ...                      ...
# 510698               339.38                -1.30                     11.0
# 510696               338.25               -10.61                     11.0
# 510695               338.10               -11.60                     11.0
# 510694               338.10               -11.15                     11.0
# 510697               338.70                -6.71                     11.0
#
#         SoC [%]
# 35770      86.6
# 35782      86.6
# 35792      86.6
# 35791      86.6
# 35790      86.6
# ...         ...
# 510698     19.6
# 510696     19.6
# 510695     19.6
# 510694     19.6
# 510697     19.6
#
# [538214 rows x 4 columns]

# %%
df.shape
# Out:
# (538214, 4)

# %%
df.describe()
# Out:
#        Battery Voltage [V]  Battery Current [A]  Battery Temperature [C]  \
# count        538214.000000        538214.000000            538214.000000
# mean            376.137015           -21.815535                16.226506
# std              10.793452            43.691556                 7.824246
# min             301.800000          -402.280000                -1.000000
# 25%             369.820000           -33.640000                10.000000
# 50%             378.930000           -12.670000                17.000000
# 75%             384.066905            -2.600000                22.000000
# max             394.660000           143.840000                32.000000
#
#              SoC [%]
# count  538214.000000
# mean       65.843678
# std        12.931754
# min        19.600000
# 25%        59.400000
# 50%        68.100000
# 75%        75.300000
# max        86.600000

# %% [markdown]
# ## Splitting the Dataset into Training and Validation Subsets

# %%
def train_test_split(df, validation_split=0.2):
  train = df.loc[:,:].values

  validation_size = int(len(train) * validation_split)

  training_set = train[:-validation_size]
  validation_set = train[-validation_size:]

  return training_set, validation_set

training_set, validation_set = train_test_split(df)
print(training_set.shape, validation_set.shape)
# Out:
# (430572, 4) (107642, 4)

# %%
print(type(training_set))
print(type(validation_set))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# Normalizing the dataset
sc = MinMaxScaler(feature_range=(-1, 1))
training_set_scaled = sc.fit_transform(training_set)
print(training_set_scaled.shape)
validation_set_scaled = sc.fit_transform(validation_set)
print(validation_set_scaled.shape)
# Out:
# (430572, 4)
# (107642, 4)

# %% [markdown]
# ## Converting the Training and Validation Subsets into Sequential Timesteps

# %%
def split_sequence(sequence, n_steps):
  X, y = list(), list()
  for i in range(len(sequence)):
    end_ix = i + n_steps
    if end_ix > len(sequence) - 1:
      break
    
    seq_x = sequence[i:end_ix,:] 
    seq_y = sequence[end_ix,-1]
    X.append(seq_x)
    y.append(seq_y)
  return np.array(X), np.array(y)
n_steps = 1
features = training_set_scaled.shape[1]

X_train, y_train = split_sequence(training_set_scaled, n_steps)
print(X_train.shape,y_train.shape)
X_val, y_val = split_sequence(validation_set_scaled, n_steps)
print(X_val.shape,y_val.shape)
# Out:
# (430571, 1, 4) (430571,)
# (107641, 1, 4) (107641,)

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# ### Defining the Model

# %%
# Defining the LSTM model
def create_model(nl):
   model = Sequential()
   if nl == 1:
      model.add(LSTM(units=256, activation="tanh", input_shape=(n_steps, features)))
      model.add(Dense(units=1,activation='linear'))
   elif nl == 2:
      model.add(LSTM(units=256, activation="tanh", input_shape=(n_steps, features), return_sequences=True))
      model.add(LSTM(units=128, activation="tanh"))
      model.add(Dense(units=1,activation='linear'))
   elif nl == 3:
      model.add(LSTM(units=256, activation="tanh", input_shape=(n_steps, features), return_sequences=True))
      model.add(LSTM(units=128, activation="tanh", return_sequences=True))
      model.add(LSTM(units=64, activation="tanh"))
      model.add(Dense(units=1,activation='linear'))
   elif nl == 4:
      model.add(LSTM(units=256, activation="tanh", input_shape=(n_steps, features), return_sequences=True))
      model.add(LSTM(units=128, activation="tanh", return_sequences=True))
      model.add(LSTM(units=64, activation="tanh", return_sequences=True))
      model.add(LSTM(units=32, activation="tanh"))
      model.add(Dense(units=1,activation='linear'))

   opt = optimizers.SGD(learning_rate=0.025)
   model.compile(optimizer=opt, loss="mean_squared_error")
   return model

# %%
tr_mse, vl_mse, tr_r2, vl_r2 = [], [], [], []
for n_layers in [1,2,3,4]:
    print(f"Model {n_layers}:")
    model = create_model(n_layers)
    history = model.fit(X_train, y_train, 
                    epochs=100, 
                    batch_size=512, 
                    validation_data=(X_val, y_val),
                    verbose=1)
    
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    plt.figure(figsize=(8.5,4.5))
    plt.grid(True,linewidth=1,color='black',alpha=1)
    plt.plot(range(len(train_loss)), train_loss, label='Training Loss', linewidth=2)
    plt.plot(range(len(val_loss)), val_loss, label='Validation Loss', linewidth=2)
    plt.xlabel('Epoch',color='black',fontsize=14)
    plt.ylabel('Loss',color='black',fontsize=14)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.legend(fontsize=14)
    plt.show()
    
    train_mse = model.evaluate(X_train, y_train, verbose=0)
    print("Train MSE:",train_mse)
    val_mse = model.evaluate(X_val, y_val, verbose=0)
    print("Validation MSE:",val_mse)
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_val)
    train_r2 = r2_score(y_train[:], train_preds)
    val_r2 = r2_score(y_val[:], test_preds)
    print("Train R2:",train_r2)
    print("Validation R2:",val_r2)
    tr_mse.append(train_mse)
    vl_mse.append(val_mse)
    tr_r2.append(train_r2)
    vl_r2.append(val_r2)
# Out:
# Model 1:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1158 - val_loss: 0.0042
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 6.5167e-04 - val_loss: 0.0011
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.1711e-04 - val_loss: 6.0483e-04
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1192e-04 - val_loss: 4.1858e-04
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 7.5466e-05 - val_loss: 3.3430e-04
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 6.0072e-05 - val_loss: 2.7994e-04
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.0970e-05 - val_loss: 2.4046e-04
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.4085e-05 - val_loss: 2.1208e-04
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.0012e-05 - val_loss: 1.8877e-04
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3.5465e-05 - val_loss: 1.6976e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.1659e-05 - val_loss: 1.5283e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.8781e-05 - val_loss: 1.3966e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.5868e-05 - val_loss: 1.2706e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.3419e-05 - val_loss: 1.1603e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.1123e-05 - val_loss: 1.0670e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.9359e-05 - val_loss: 9.7344e-05
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.7660e-05 - val_loss: 9.0255e-05
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.6035e-05 - val_loss: 8.1868e-05
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.4725e-05 - val_loss: 7.5929e-05
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.3491e-05 - val_loss: 6.9728e-05
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.2550e-05 - val_loss: 6.4462e-05
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.1560e-05 - val_loss: 6.0068e-05
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 1.0555e-05 - val_loss: 5.5954e-05
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 9.9404e-06 - val_loss: 5.2569e-05
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 9.3489e-06 - val_loss: 4.9147e-05
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 8.7038e-06 - val_loss: 4.5823e-05
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 8.1195e-06 - val_loss: 4.3281e-05
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 7.7178e-06 - val_loss: 4.0386e-05
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 7.2739e-06 - val_loss: 3.8128e-05
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 6.8823e-06 - val_loss: 3.6281e-05
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 6.5659e-06 - val_loss: 3.4663e-05
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.2294e-06 - val_loss: 3.2723e-05
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.0074e-06 - val_loss: 3.1195e-05
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 5.8522e-06 - val_loss: 2.9687e-05
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 5.5497e-06 - val_loss: 2.8352e-05
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 5.3629e-06 - val_loss: 2.6926e-05
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 5.2252e-06 - val_loss: 2.6170e-05
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.0604e-06 - val_loss: 2.4876e-05
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.9076e-06 - val_loss: 2.4221e-05
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 4.7979e-06 - val_loss: 2.3084e-05
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 4.6755e-06 - val_loss: 2.2548e-05
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 4.5895e-06 - val_loss: 2.1833e-05
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.4711e-06 - val_loss: 2.0994e-05
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.3800e-06 - val_loss: 2.0417e-05
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.3498e-06 - val_loss: 1.9972e-05
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 4.2549e-06 - val_loss: 1.9471e-05
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.1723e-06 - val_loss: 1.8988e-05
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 4.1239e-06 - val_loss: 1.8511e-05
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 4.0872e-06 - val_loss: 1.8112e-05
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 4.0448e-06 - val_loss: 1.7831e-05
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.9821e-06 - val_loss: 1.7589e-05
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.9306e-06 - val_loss: 1.7003e-05
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.8729e-06 - val_loss: 1.6463e-05
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.8513e-06 - val_loss: 1.6474e-05
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.8529e-06 - val_loss: 1.6100e-05
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.7837e-06 - val_loss: 1.5874e-05
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.7706e-06 - val_loss: 1.5607e-05
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.7482e-06 - val_loss: 1.5487e-05
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.7098e-06 - val_loss: 1.5230e-05
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.7154e-06 - val_loss: 1.5150e-05
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.6478e-06 - val_loss: 1.4735e-05
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.6498e-06 - val_loss: 1.4642e-05
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.6364e-06 - val_loss: 1.4481e-05
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.5959e-06 - val_loss: 1.4143e-05
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.5830e-06 - val_loss: 1.4314e-05
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.5761e-06 - val_loss: 1.4079e-05
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.5429e-06 - val_loss: 1.3934e-05
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.5320e-06 - val_loss: 1.3793e-05
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.4937e-06 - val_loss: 1.3567e-05
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.4914e-06 - val_loss: 1.3550e-05
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.4849e-06 - val_loss: 1.3464e-05
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.4647e-06 - val_loss: 1.3116e-05
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.4409e-06 - val_loss: 1.3146e-05
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.4373e-06 - val_loss: 1.3202e-05
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.4401e-06 - val_loss: 1.3092e-05
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.4125e-06 - val_loss: 1.2873e-05
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.3980e-06 - val_loss: 1.2884e-05
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.3885e-06 - val_loss: 1.2819e-05
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.3946e-06 - val_loss: 1.2627e-05
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.3576e-06 - val_loss: 1.2529e-05
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.3736e-06 - val_loss: 1.2429e-05
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.3465e-06 - val_loss: 1.2515e-05
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.3441e-06 - val_loss: 1.2310e-05
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.3266e-06 - val_loss: 1.2310e-05
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.3177e-06 - val_loss: 1.2186e-05
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.3214e-06 - val_loss: 1.2244e-05
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.3185e-06 - val_loss: 1.2057e-05
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.3045e-06 - val_loss: 1.2038e-05
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.2815e-06 - val_loss: 1.2099e-05
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.2895e-06 - val_loss: 1.1920e-05
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.2590e-06 - val_loss: 1.1867e-05
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2445e-06 - val_loss: 1.1825e-05
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2606e-06 - val_loss: 1.1840e-05
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2556e-06 - val_loss: 1.1720e-05
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2314e-06 - val_loss: 1.1665e-05
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.2391e-06 - val_loss: 1.1660e-05
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2217e-06 - val_loss: 1.1613e-05
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2220e-06 - val_loss: 1.1473e-05
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2268e-06 - val_loss: 1.1568e-05
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.2055e-06 - val_loss: 1.1496e-05
# Train MSE: 3.2041637041402282e-06
# Validation MSE: 1.1495979379105847e-05
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 12s 873us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 3s 915us/step
# Train R2: 0.9999870503065624
# Validation R2: 0.9999510486766194
# Model 2:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.2300 - val_loss: 0.2435
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0741 - val_loss: 0.0102
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 4.4784e-04 - val_loss: 0.0014
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 2.6578e-04 - val_loss: 0.0010
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1.8973e-04 - val_loss: 8.2930e-04
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 1.5135e-04 - val_loss: 7.1390e-04
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1.2864e-04 - val_loss: 6.2251e-04
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1.1453e-04 - val_loss: 5.6157e-04
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1.0398e-04 - val_loss: 5.2352e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 9.8639e-05 - val_loss: 4.8720e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 9.3045e-05 - val_loss: 4.5198e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 8.9096e-05 - val_loss: 4.3283e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 8.3505e-05 - val_loss: 4.0219e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 8.0835e-05 - val_loss: 3.8835e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 7.7467e-05 - val_loss: 3.6647e-04
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 7.3554e-05 - val_loss: 3.4972e-04
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 7.0679e-05 - val_loss: 3.4109e-04
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 6.8700e-05 - val_loss: 3.2369e-04
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 6.5877e-05 - val_loss: 3.0656e-04
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 6.2926e-05 - val_loss: 2.9376e-04
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 6.0408e-05 - val_loss: 2.8542e-04
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 5.8714e-05 - val_loss: 2.7559e-04
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 5.6561e-05 - val_loss: 2.6508e-04
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 5.4941e-05 - val_loss: 2.5153e-04
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 5.3019e-05 - val_loss: 2.4485e-04
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 5.1762e-05 - val_loss: 2.3312e-04
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.9584e-05 - val_loss: 2.2837e-04
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.8180e-05 - val_loss: 2.1982e-04
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 4.7406e-05 - val_loss: 2.1236e-04
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.5584e-05 - val_loss: 2.0575e-04
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.4614e-05 - val_loss: 1.9908e-04
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.3474e-05 - val_loss: 1.9294e-04
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.2584e-05 - val_loss: 1.8665e-04
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 4.1399e-05 - val_loss: 1.8154e-04
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.9937e-05 - val_loss: 1.7571e-04
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.9427e-05 - val_loss: 1.7145e-04
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.8744e-05 - val_loss: 1.6721e-04
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.7994e-05 - val_loss: 1.6145e-04
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.7312e-05 - val_loss: 1.5757e-04
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.6584e-05 - val_loss: 1.5391e-04
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.5713e-05 - val_loss: 1.4925e-04
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.5115e-05 - val_loss: 1.4672e-04
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.4585e-05 - val_loss: 1.4155e-04
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3.4047e-05 - val_loss: 1.3988e-04
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 3.3600e-05 - val_loss: 1.3661e-04
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.3019e-05 - val_loss: 1.3294e-04
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.2566e-05 - val_loss: 1.3038e-04
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.1977e-05 - val_loss: 1.2693e-04
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.1976e-05 - val_loss: 1.2562e-04
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.1347e-05 - val_loss: 1.2154e-04
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.1095e-05 - val_loss: 1.1995e-04
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.0663e-05 - val_loss: 1.1779e-04
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.0498e-05 - val_loss: 1.1646e-04
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.0087e-05 - val_loss: 1.1520e-04
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.9639e-05 - val_loss: 1.1257e-04
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.9470e-05 - val_loss: 1.1003e-04
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.9130e-05 - val_loss: 1.1059e-04
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.8933e-05 - val_loss: 1.0751e-04
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.8783e-05 - val_loss: 1.0538e-04
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.8564e-05 - val_loss: 1.0379e-04
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.8224e-05 - val_loss: 1.0355e-04
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.8084e-05 - val_loss: 1.0167e-04
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.7868e-05 - val_loss: 1.0033e-04
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.7722e-05 - val_loss: 9.9267e-05
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.7351e-05 - val_loss: 9.7125e-05
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 2.7324e-05 - val_loss: 9.6487e-05
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 2.7063e-05 - val_loss: 9.5094e-05
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.6946e-05 - val_loss: 9.4417e-05
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.6686e-05 - val_loss: 9.4515e-05
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.6674e-05 - val_loss: 9.1989e-05
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.6517e-05 - val_loss: 9.1146e-05
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 2.6327e-05 - val_loss: 9.0072e-05
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 2.6295e-05 - val_loss: 8.8517e-05
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 2.6121e-05 - val_loss: 8.7491e-05
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 2.6203e-05 - val_loss: 8.7827e-05
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 2.5912e-05 - val_loss: 8.6991e-05
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.5809e-05 - val_loss: 8.6692e-05
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.5639e-05 - val_loss: 8.5520e-05
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.5650e-05 - val_loss: 8.6110e-05
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 2.5440e-05 - val_loss: 8.3332e-05
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 2.5320e-05 - val_loss: 8.3560e-05
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 2.5341e-05 - val_loss: 8.3267e-05
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.5193e-05 - val_loss: 8.1955e-05
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.5190e-05 - val_loss: 8.1503e-05
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.5047e-05 - val_loss: 8.0243e-05
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2.4954e-05 - val_loss: 8.0983e-05
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.4855e-05 - val_loss: 7.9488e-05
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4750e-05 - val_loss: 7.8405e-05
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4622e-05 - val_loss: 7.8064e-05
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4789e-05 - val_loss: 7.7676e-05
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.4677e-05 - val_loss: 7.7189e-05
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4564e-05 - val_loss: 7.6805e-05
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4484e-05 - val_loss: 7.7020e-05
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4448e-05 - val_loss: 7.6386e-05
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.4275e-05 - val_loss: 7.5501e-05
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.4251e-05 - val_loss: 7.4905e-05
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.4172e-05 - val_loss: 7.4716e-05
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 2.4125e-05 - val_loss: 7.4365e-05
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 2.4108e-05 - val_loss: 7.3309e-05
# Train MSE: 2.4027553081396036e-05
# Validation MSE: 7.330938387895003e-05
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 10s 746us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 3s 758us/step
# Train R2: 0.9999028925094006
# Validation R2: 0.9996878397380433
# Model 3:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2469 - val_loss: 0.4124
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2431 - val_loss: 0.4041
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2356 - val_loss: 0.3682
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2024 - val_loss: 0.1892
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0517 - val_loss: 0.0099
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 6.3732e-04 - val_loss: 0.0017
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4.0731e-04 - val_loss: 0.0013
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.1259e-04 - val_loss: 0.0011
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.6311e-04 - val_loss: 9.1066e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 2.3316e-04 - val_loss: 8.1826e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 2.1374e-04 - val_loss: 7.4659e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 2.0123e-04 - val_loss: 6.8710e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.9082e-04 - val_loss: 6.5668e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.8368e-04 - val_loss: 6.2319e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.8009e-04 - val_loss: 6.0219e-04
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.7341e-04 - val_loss: 5.7517e-04
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.7056e-04 - val_loss: 5.6308e-04
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.6773e-04 - val_loss: 5.4267e-04
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.6451e-04 - val_loss: 5.3557e-04
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.6100e-04 - val_loss: 5.2180e-04
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.5852e-04 - val_loss: 5.1358e-04
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.5621e-04 - val_loss: 5.0125e-04
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.5397e-04 - val_loss: 4.7964e-04
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.5062e-04 - val_loss: 4.7137e-04
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.4781e-04 - val_loss: 4.6810e-04
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.4616e-04 - val_loss: 4.5549e-04
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.4329e-04 - val_loss: 4.5199e-04
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.4089e-04 - val_loss: 4.4656e-04
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.3894e-04 - val_loss: 4.3809e-04
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.3710e-04 - val_loss: 4.2038e-04
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.3473e-04 - val_loss: 4.1598e-04
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.3409e-04 - val_loss: 4.0166e-04
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.3116e-04 - val_loss: 3.9854e-04
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.2996e-04 - val_loss: 3.9758e-04
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.2827e-04 - val_loss: 3.9410e-04
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.2654e-04 - val_loss: 3.8587e-04
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.2516e-04 - val_loss: 3.8211e-04
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.2365e-04 - val_loss: 3.7483e-04
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.2211e-04 - val_loss: 3.6635e-04
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.2120e-04 - val_loss: 3.6121e-04
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.1996e-04 - val_loss: 3.5699e-04
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.1832e-04 - val_loss: 3.5011e-04
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1715e-04 - val_loss: 3.4004e-04
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1638e-04 - val_loss: 3.4259e-04
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1522e-04 - val_loss: 3.3603e-04
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1402e-04 - val_loss: 3.3018e-04
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1277e-04 - val_loss: 3.2223e-04
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1205e-04 - val_loss: 3.2119e-04
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.1119e-04 - val_loss: 3.1299e-04
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.0950e-04 - val_loss: 3.0725e-04
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.0856e-04 - val_loss: 3.0606e-04
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0788e-04 - val_loss: 3.0447e-04
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0687e-04 - val_loss: 2.9806e-04
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0611e-04 - val_loss: 2.9261e-04
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0528e-04 - val_loss: 2.9080e-04
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0474e-04 - val_loss: 2.9076e-04
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0348e-04 - val_loss: 2.8517e-04
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0260e-04 - val_loss: 2.8366e-04
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.0230e-04 - val_loss: 2.8183e-04
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.0133e-04 - val_loss: 2.7628e-04
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.0075e-04 - val_loss: 2.7588e-04
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 1.0009e-04 - val_loss: 2.7059e-04
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.9537e-05 - val_loss: 2.7038e-04
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.8497e-05 - val_loss: 2.6799e-04
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.8234e-05 - val_loss: 2.6232e-04
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.7676e-05 - val_loss: 2.5359e-04
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.6746e-05 - val_loss: 2.5502e-04
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.6205e-05 - val_loss: 2.5355e-04
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.5578e-05 - val_loss: 2.5022e-04
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.4941e-05 - val_loss: 2.4623e-04
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.4075e-05 - val_loss: 2.4386e-04
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.4295e-05 - val_loss: 2.4386e-04
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.3087e-05 - val_loss: 2.4066e-04
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9.2687e-05 - val_loss: 2.3773e-04
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9.1895e-05 - val_loss: 2.3534e-04
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9.1705e-05 - val_loss: 2.3535e-04
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.1282e-05 - val_loss: 2.3520e-04
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.0472e-05 - val_loss: 2.2910e-04
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 9.0165e-05 - val_loss: 2.2755e-04
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.9772e-05 - val_loss: 2.2694e-04
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.9618e-05 - val_loss: 2.2477e-04
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.8991e-05 - val_loss: 2.2469e-04
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 8.8270e-05 - val_loss: 2.2177e-04
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.8494e-05 - val_loss: 2.2232e-04
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.7101e-05 - val_loss: 2.1732e-04
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.7267e-05 - val_loss: 2.1878e-04
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.6804e-05 - val_loss: 2.1507e-04
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.6502e-05 - val_loss: 2.1501e-04
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.5795e-05 - val_loss: 2.1240e-04
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 8.5614e-05 - val_loss: 2.1006e-04
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 8.5126e-05 - val_loss: 2.0653e-04
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.4702e-05 - val_loss: 2.0773e-04
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.4155e-05 - val_loss: 2.0441e-04
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.4313e-05 - val_loss: 2.0592e-04
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.3486e-05 - val_loss: 2.0318e-04
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.2950e-05 - val_loss: 2.0226e-04
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.2903e-05 - val_loss: 2.0031e-04
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.2566e-05 - val_loss: 1.9589e-04
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 8.2069e-05 - val_loss: 1.9686e-04
# Train MSE: 8.193546818802133e-05
# Validation MSE: 0.00019685762526933104
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 11s 829us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 3s 800us/step
# Train R2: 0.9996688564156194
# Validation R2: 0.9991617560380025
# Model 4:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.2480 - val_loss: 0.4181
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2465 - val_loss: 0.4090
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2475 - val_loss: 0.4192
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2470 - val_loss: 0.4141
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2478 - val_loss: 0.4176
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2472 - val_loss: 0.4171
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2465 - val_loss: 0.4107
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2468 - val_loss: 0.4138
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2464 - val_loss: 0.4107
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2451 - val_loss: 0.4098
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2453 - val_loss: 0.4054
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2439 - val_loss: 0.4057
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2419 - val_loss: 0.4026
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.2385 - val_loss: 0.3913
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.2278 - val_loss: 0.3551
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.1870 - val_loss: 0.1271
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0270 - val_loss: 0.0075
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9.3533e-04 - val_loss: 0.0024
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 7.0581e-04 - val_loss: 0.0019
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 5.8942e-04 - val_loss: 0.0016
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 5.2162e-04 - val_loss: 0.0014
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4.7833e-04 - val_loss: 0.0013
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4.4825e-04 - val_loss: 0.0012
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4.2647e-04 - val_loss: 0.0012
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4.0819e-04 - val_loss: 0.0011
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.9448e-04 - val_loss: 0.0011
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.8391e-04 - val_loss: 0.0010
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.7487e-04 - val_loss: 0.0010
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.6977e-04 - val_loss: 9.9398e-04
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.6054e-04 - val_loss: 9.7601e-04
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.5401e-04 - val_loss: 9.5185e-04
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.4925e-04 - val_loss: 9.4711e-04
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.4372e-04 - val_loss: 9.2807e-04
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.3688e-04 - val_loss: 9.1006e-04
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.3281e-04 - val_loss: 8.9847e-04
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.2849e-04 - val_loss: 8.8179e-04
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.2216e-04 - val_loss: 8.7518e-04
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.1786e-04 - val_loss: 8.5205e-04
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.1235e-04 - val_loss: 8.4511e-04
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.0795e-04 - val_loss: 8.2432e-04
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.0462e-04 - val_loss: 8.2036e-04
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3.0101e-04 - val_loss: 8.0125e-04
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.9626e-04 - val_loss: 7.9290e-04
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.9305e-04 - val_loss: 7.9901e-04
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.8796e-04 - val_loss: 7.6603e-04
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.8544e-04 - val_loss: 7.6511e-04
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.8178e-04 - val_loss: 7.3971e-04
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.7877e-04 - val_loss: 7.2796e-04
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 2.7369e-04 - val_loss: 7.2445e-04
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 2.7158e-04 - val_loss: 7.1986e-04
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.6991e-04 - val_loss: 7.0441e-04
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.6536e-04 - val_loss: 7.0176e-04
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.6139e-04 - val_loss: 6.8755e-04
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.6028e-04 - val_loss: 6.6976e-04
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.5658e-04 - val_loss: 6.7054e-04
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.5294e-04 - val_loss: 6.4994e-04
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.5113e-04 - val_loss: 6.3886e-04
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.4962e-04 - val_loss: 6.4712e-04
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.4676e-04 - val_loss: 6.1678e-04
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.4467e-04 - val_loss: 6.2746e-04
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.4195e-04 - val_loss: 6.0957e-04
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.3954e-04 - val_loss: 5.9402e-04
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.3634e-04 - val_loss: 5.9220e-04
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.3364e-04 - val_loss: 5.8044e-04
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.3110e-04 - val_loss: 5.6885e-04
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.2983e-04 - val_loss: 5.7559e-04
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.2855e-04 - val_loss: 5.6448e-04
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.2466e-04 - val_loss: 5.5721e-04
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.2342e-04 - val_loss: 5.5884e-04
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.2122e-04 - val_loss: 5.5254e-04
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.1867e-04 - val_loss: 5.4180e-04
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.1859e-04 - val_loss: 5.3784e-04
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.1558e-04 - val_loss: 5.3152e-04
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.1437e-04 - val_loss: 5.2104e-04
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.1198e-04 - val_loss: 5.1907e-04
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.1021e-04 - val_loss: 5.0178e-04
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.0922e-04 - val_loss: 5.0879e-04
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.0732e-04 - val_loss: 4.9892e-04
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.0473e-04 - val_loss: 4.9372e-04
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.0401e-04 - val_loss: 4.9835e-04
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.0169e-04 - val_loss: 4.8615e-04
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2.0116e-04 - val_loss: 4.8134e-04
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9903e-04 - val_loss: 4.7781e-04
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9761e-04 - val_loss: 4.7520e-04
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9646e-04 - val_loss: 4.6993e-04
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9477e-04 - val_loss: 4.6308e-04
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9292e-04 - val_loss: 4.6453e-04
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9179e-04 - val_loss: 4.5803e-04
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.9026e-04 - val_loss: 4.4833e-04
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8893e-04 - val_loss: 4.4332e-04
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8791e-04 - val_loss: 4.3831e-04
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8550e-04 - val_loss: 4.3288e-04
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8454e-04 - val_loss: 4.2910e-04
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8346e-04 - val_loss: 4.2491e-04
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8181e-04 - val_loss: 4.2759e-04
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8046e-04 - val_loss: 4.1592e-04
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.8046e-04 - val_loss: 4.1488e-04
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.7837e-04 - val_loss: 4.1159e-04
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.7685e-04 - val_loss: 4.1074e-04
# Train MSE: 0.00017666253552306443
# Validation MSE: 0.0004107449494767934
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 12s 867us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 3s 980us/step
# Train R2: 0.9992860154836841
# Validation R2: 0.9982509974717287

# %% [markdown]
# ## Performance Metrics

# %%
from tabulate import tabulate

tr_mse = [float(el) for el in tr_mse]
vl_mse = [float(el) for el in vl_mse]
tr_r2 = [float(el) for el in tr_r2]
vl_r2 = [float(el) for el in vl_r2]

res = []
layer_info = [1,2,3,4]
for i in range(len(layer_info)):
  el = []
  el.append(layer_info[i])
  el.append(round(tr_mse[i]*100,4))
  el.append(round(vl_mse[i]*100,4))
  el.append(round(tr_r2[i]*100,4))
  el.append(round(vl_r2[i]*100,4))
  res.append(el)
cols = ["Number of Hidden Layers","Train MSE","Validation MSE","Train R2","Validation R2"]

print(tabulate(res, headers=cols, tablefmt="grid", colalign=("center", "center", "center", "center", "center")))
# Out:
# +---------------------------+-------------+------------------+------------+-----------------+
# |  Number of Hidden Layers  |  Train MSE  |  Validation MSE  |  Train R2  |  Validation R2  |
# +===========================+=============+==================+============+=================+
# |             1             |   0.0003    |      0.0011      |  99.9987   |     99.9951     |
# +---------------------------+-------------+------------------+------------+-----------------+
# |             2             |   0.0024    |      0.0073      |  99.9903   |     99.9688     |
# +---------------------------+-------------+------------------+------------+-----------------+
# |             3             |   0.0082    |      0.0197      |  99.9669   |     99.9162     |
# +---------------------------+-------------+------------------+------------+-----------------+
# |             4             |   0.0177    |      0.0411      |  99.9286   |     99.8251     |
# +---------------------------+-------------+------------------+------------+-----------------+

# %% [markdown]
# After the analysing the performance metrics, the optimal number of hidden layer(s) was found to be **1** as it had the least MSE and highest R2 score.
# ***
