# %% [markdown]
# # Optimal Number of Nodes for LSTM

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from keras.models import save_model

from matplotlib.ticker import MaxNLocator

# %%
# Reading the dataset
dft1 = pd.read_csv('TripA04.csv')
dft2 = pd.read_csv('TripA06.csv')
dft3 = pd.read_csv('TripA08.csv')
dft4 = pd.read_csv('TripA12.csv')
dft5 = pd.read_csv('TripA16.csv')
dft6 = pd.read_csv('TripA20.csv')
dft7 = pd.read_csv('TripA24.csv')
dft8 = pd.read_csv('TripA28.csv')
dft9 = pd.read_csv('TripA32.csv')

dft10 = pd.read_csv('TripB01.csv')
dft11 = pd.read_csv('TripB03.csv')
dft12 = pd.read_csv('TripB10.csv')
dft13 = pd.read_csv('TripB15.csv')
dft14 = pd.read_csv('TripB20.csv')
dft15 = pd.read_csv('TripB23.csv')
dft16 = pd.read_csv('TripB25.csv')
dft17 = pd.read_csv('TripB27.csv')
dft18 = pd.read_csv('TripB30.csv')
dft19 = pd.read_csv('TripB33.csv')
dft20 = pd.read_csv('TripB38.csv')


dft21 = pd.read_csv('TripA02.csv')
dft22 = pd.read_csv('TripA03.csv')
dft23 = pd.read_csv('TripA07.csv')
dft24 = pd.read_csv('TripA15.csv')
dft25 = pd.read_csv('TripA21.csv')
dft26 = pd.read_csv('TripA25.csv')
dft27 = pd.read_csv('TripA27.csv')

dft28 = pd.read_csv('TripB05.csv')
dft29 = pd.read_csv('TripB07.csv')
dft30 = pd.read_csv('TripB13.csv')
dft31 = pd.read_csv('TripB16.csv')
dft32 = pd.read_csv('TripB22.csv')
dft33 = pd.read_csv('TripB28.csv')
dft34 = pd.read_csv('TripB31.csv')
dft35 = pd.read_csv('TripB37.csv')
df = pd.concat([dft1, dft2, dft3, dft4, dft5, dft6, dft7, dft8, dft9, dft10, dft11, dft12, dft13, dft14, dft15, dft16, dft17, dft18, dft19, 
                dft20, dft21, dft22, dft23, dft24, dft25, dft26, dft27, dft28, dft29, dft30, dft31, dft32, dft33, dft34, dft35], ignore_index=True)
df.shape
# Out:
# (538214, 102)

# %%
df.describe()
# Out:
#             Time [s]  Velocity [km/h]  Elevation [m]   Throttle [%]  \
# count  538214.000000    538214.000000  538214.000000  538214.000000
# mean      927.042681        48.204922     524.400663      30.368202
# std       671.750161        36.031693      41.051019      17.871018
# min         0.000000         0.000000     449.000000       0.000000
# 25%       385.300000        19.989925     484.000000      17.280000
# 50%       814.800000        44.570000     520.000000      35.130000
# 75%      1335.300000        71.580000     556.520000      43.780000
# max      3251.700000       152.000000     664.990000      99.630000
#
#        Motor Torque [Nm]  Longitudinal Acceleration [m/s^2]  \
# count      538214.000000                      538214.000000
# mean           11.335276                           0.003850
# std            36.659281                           0.664698
# min           -87.500000                          -9.030000
# 25%             0.000000                          -0.240000
# 50%             7.000000                          -0.010000
# 75%            23.500000                           0.220000
# max           249.500000                           4.460000
#
#        Regenerative Braking Signal   Battery Voltage [V]  Battery Current [A]  \
# count                 538214.000000        538214.000000        538214.000000
# mean                       0.058006           376.137015           -21.815535
# std                        0.233630            10.793452            43.691556
# min                        0.000000           301.800000          -402.280000
# 25%                        0.000000           369.820000           -33.640000
# 50%                        0.000000           378.930000           -12.670000
# 75%                        0.000000           384.066905            -2.600000
# max                        1.000000           394.660000           143.840000
#
#        Battery Temperature [C]  ...  Temperature Footweel Co-Driver [°C]  \
# count            496092.000000  ...                         18223.000000
# mean                 16.707009  ...                            23.509571
# std                   7.965289  ...                             4.190296
# min                  -1.000000  ...                             0.490000
# 25%                  10.000000  ...                            23.010000
# 50%                  18.000000  ...                            24.020000
# 75%                  25.000000  ...                            25.120000
# max                  32.000000  ...                            29.110000
#
#        Temperature Feetvent Co-Driver [°C]  Temperature Feetvent Driver [°C]  \
# count                         18223.000000                      18223.000000
# mean                             44.573138                         44.204625
# std                               7.899812                          8.072591
# min                              -0.740000                         -0.650000
# 25%                              43.310000                         42.640000
# 50%                              44.390000                         43.780000
# 75%                              45.820000                         45.405000
# max                              55.210000                         55.910000
#
#        Temperature Head Co-Driver [°C]  Temperature Head Driver [°C]  \
# count                     18223.000000                  18223.000000
# mean                         17.991491                     19.900232
# std                           3.958080                      3.915668
# min                           3.980000                      4.680000
# 25%                          18.595000                     20.390000
# 50%                          19.500000                     21.170000
# 75%                          19.860000                     21.700000
# max                          21.350000                     23.870000
#
#        Temperature Vent right [°C]   Temperature Vent central right [°C]  \
# count                  18223.000000                         18223.000000
# mean                      33.153629                            32.101083
# std                        6.962805                             7.177824
# min                        0.310000                             0.400000
# 25%                       33.020000                            32.870000
# 50%                       33.870000                            33.880000
# 75%                       35.220000                            35.050000
# max                       42.900000                            39.760000
#
#        Temperature Vent central left [°C]  Temperature Vent right [°C]  \
# count                        18223.000000                 18223.000000
# mean                            35.385577                    31.368940
# std                              8.173045                     6.866679
# min                              0.660000                     0.920000
# 25%                             35.090000                    31.300000
# 50%                             36.270000                    32.080000
# 75%                             38.280000                    33.730000
# max                             46.480000                    41.070000
#
#        Battery Temperature [�C]
# count              23899.000000
# mean                   3.714842
# std                    1.633322
# min                    1.000000
# 25%                    2.000000
# 50%                    4.000000
# 75%                    5.000000
# max                    6.000000
#
# [8 rows x 102 columns]

# %%
# Extracting input variables and target variable from the dataset
attr = ['Battery Voltage [V]','Battery Current [A]','Battery Temperature [C]','SoC [%]']
df = df[:].loc[:,attr]

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# Battery Voltage [V]            0
# Battery Current [A]            0
# Battery Temperature [C]    42122
# SoC [%]                     5811
# dtype: int64

# %%
df = df.fillna(method = 'bfill')
df.isna().sum()
# Out:
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\214754001.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = 'bfill')
# Battery Voltage [V]        0
# Battery Current [A]        0
# Battery Temperature [C]    0
# SoC [%]                    0
# dtype: int64

# %%
df = df.sort_values(by='SoC [%]', ascending=False)
df
# Out:
#         Battery Voltage [V]  Battery Current [A]  Battery Temperature [C]  \
# 35770                391.57                -8.96                     26.0
# 35782                390.97               -16.99                     26.0
# 35792                390.83               -17.85                     26.0
# 35791                390.82               -17.96                     26.0
# 35790                390.87               -17.66                     26.0
# ...                     ...                  ...                      ...
# 510698               339.38                -1.30                     11.0
# 510696               338.25               -10.61                     11.0
# 510695               338.10               -11.60                     11.0
# 510694               338.10               -11.15                     11.0
# 510697               338.70                -6.71                     11.0
#
#         SoC [%]
# 35770      86.6
# 35782      86.6
# 35792      86.6
# 35791      86.6
# 35790      86.6
# ...         ...
# 510698     19.6
# 510696     19.6
# 510695     19.6
# 510694     19.6
# 510697     19.6
#
# [538214 rows x 4 columns]

# %%
df.shape
# Out:
# (538214, 4)

# %%
df.describe()
# Out:
#        Battery Voltage [V]  Battery Current [A]  Battery Temperature [C]  \
# count        538214.000000        538214.000000            538214.000000
# mean            376.137015           -21.815535                16.226506
# std              10.793452            43.691556                 7.824246
# min             301.800000          -402.280000                -1.000000
# 25%             369.820000           -33.640000                10.000000
# 50%             378.930000           -12.670000                17.000000
# 75%             384.066905            -2.600000                22.000000
# max             394.660000           143.840000                32.000000
#
#              SoC [%]
# count  538214.000000
# mean       65.843678
# std        12.931754
# min        19.600000
# 25%        59.400000
# 50%        68.100000
# 75%        75.300000
# max        86.600000

# %% [markdown]
# ## Splitting the Dataset into Training and Validation Subsets

# %%
def train_test_split(df, validation_split=0.2):
  train = df.loc[:,:].values

  validation_size = int(len(train) * validation_split)

  training_set = train[:-validation_size]
  validation_set = train[-validation_size:]

  return training_set, validation_set

training_set, validation_set = train_test_split(df)
print(training_set.shape, validation_set.shape)
# Out:
# (430572, 4) (107642, 4)

# %%
print(type(training_set))
print(type(validation_set))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# Normalizing the dataset
sc = MinMaxScaler(feature_range=(-1, 1))
training_set_scaled = sc.fit_transform(training_set)
print(training_set_scaled.shape)
validation_set_scaled = sc.fit_transform(validation_set)
print(validation_set_scaled.shape)
# Out:
# (430572, 4)
# (107642, 4)

# %% [markdown]
# ## Converting the Training and Validation Subsets into Sequential Timesteps

# %%
def split_sequence(sequence, n_steps):
  X, y = list(), list()
  for i in range(len(sequence)):
    end_ix = i + n_steps
    if end_ix > len(sequence) - 1:
      break
    
    seq_x = sequence[i:end_ix,:]  
    seq_y = sequence[end_ix,-1]  
    X.append(seq_x)
    y.append(seq_y)
  return np.array(X), np.array(y)
n_steps = 1
features = training_set_scaled.shape[1]

X_train, y_train = split_sequence(training_set_scaled, n_steps)
print(X_train.shape,y_train.shape)
X_val, y_val = split_sequence(validation_set_scaled, n_steps)
print(X_val.shape,y_val.shape)
# Out:
# (430571, 1, 4) (430571,)
# (107641, 1, 4) (107641,)

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# ### Defining the Model

# %%
def create_model(cf):
   model = Sequential()
   if cf == 1:
      model.add(LSTM(units=256, activation="tanh", input_shape=(n_steps, features)))
      model.add(Dense(units=1, activation="linear"))
   elif cf == 2:
      model.add(LSTM(units=128, activation="tanh", input_shape=(n_steps, features)))
      model.add(Dense(units=1, activation="linear"))
   elif cf == 3:
      model.add(LSTM(units=64, activation="tanh", input_shape=(n_steps, features)))
      model.add(Dense(units=1, activation="linear"))
   elif cf == 4:
      model.add(LSTM(units=32, activation="tanh", input_shape=(n_steps, features)))
      model.add(Dense(units=1, activation="linear"))
   
   # Compiling the model
   opt = optimizers.SGD(learning_rate=0.025)
   model.compile(optimizer=opt, loss="mean_squared_error")
   return model

# %%
tr_mse, vl_mse, tr_r2, vl_r2 = [], [], [], []
for n_layers in [1,2,3,4]:
    print(f"Model {n_layers}:")
    model = create_model(n_layers)
    history = model.fit(X_train, y_train, 
                    epochs=100, 
                    batch_size=512, 
                    validation_data=(X_val, y_val), 
                    verbose=1)
    
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    plt.figure(figsize=(8.5,4.5))
    plt.grid(True,linewidth=1,color='black',alpha=1)
    plt.plot(range(len(train_loss)), train_loss, linewidth=2, label='Training Loss')
    plt.plot(range(len(val_loss)), val_loss, linewidth=2, label='Validation Loss')
    plt.xlabel('Epoch',color='black',fontsize=14)
    plt.ylabel('Loss',color='black',fontsize=14)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.legend(fontsize=14)
    plt.show()
    
    train_mse = model.evaluate(X_train, y_train, verbose=0)
    train_mse = "{:.6f}".format(train_mse)
    print("Train MSE:",train_mse)
    val_mse = model.evaluate(X_val, y_val, verbose=0)
    val_mse = "{:.6f}".format(val_mse)
    print("Validation MSE:",val_mse)
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_val)
    train_r2 = r2_score(y_train[:], train_preds)
    val_r2 = r2_score(y_val[:], test_preds)
    print("Train R2:",round(train_r2,6))
    print("Validation R2:",round(val_r2,6))
    tr_mse.append(train_mse)
    vl_mse.append(val_mse)
    tr_r2.append(train_r2)
    vl_r2.append(val_r2)
    model_filename = f"LSTM_SoC_Updated8{n_layers}.h5"
    save_model(model, model_filename)
# Out:
# Model 1:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1249 - val_loss: 0.0033
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3.8372e-04 - val_loss: 7.0125e-04
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2340e-04 - val_loss: 4.5260e-04
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 8.0282e-05 - val_loss: 3.5368e-04
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6.1962e-05 - val_loss: 2.9105e-04
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.2333e-05 - val_loss: 2.5312e-04
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 4.6315e-05 - val_loss: 2.2558e-04
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.1528e-05 - val_loss: 2.0005e-04
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.7410e-05 - val_loss: 1.8233e-04
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3.3155e-05 - val_loss: 1.6370e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3.0257e-05 - val_loss: 1.4935e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.7485e-05 - val_loss: 1.3872e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 2.4866e-05 - val_loss: 1.2630e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 2.2659e-05 - val_loss: 1.1548e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.0250e-05 - val_loss: 1.0586e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.8854e-05 - val_loss: 9.9053e-05
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.7336e-05 - val_loss: 8.9915e-05
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.5998e-05 - val_loss: 8.3969e-05
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.4426e-05 - val_loss: 7.7510e-05
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.3572e-05 - val_loss: 7.2501e-05
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2709e-05 - val_loss: 6.6762e-05
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1733e-05 - val_loss: 6.1749e-05
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.0921e-05 - val_loss: 5.7895e-05
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.0134e-05 - val_loss: 5.5053e-05
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.4793e-06 - val_loss: 5.0984e-05
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 8.9570e-06 - val_loss: 4.7925e-05
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 8.5879e-06 - val_loss: 4.5746e-05
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 8.0823e-06 - val_loss: 4.2768e-05
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 7.7168e-06 - val_loss: 4.0837e-05
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 7.3658e-06 - val_loss: 3.8859e-05
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 7.0046e-06 - val_loss: 3.6753e-05
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 6.7089e-06 - val_loss: 3.5036e-05
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 6.4438e-06 - val_loss: 3.3209e-05
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 6.1796e-06 - val_loss: 3.1441e-05
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 5.9497e-06 - val_loss: 3.0267e-05
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.7825e-06 - val_loss: 2.9193e-05
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 5.6142e-06 - val_loss: 2.8154e-05
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 5.4475e-06 - val_loss: 2.7213e-05
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 5.3196e-06 - val_loss: 2.6154e-05
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 5.1801e-06 - val_loss: 2.5189e-05
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 5.0576e-06 - val_loss: 2.4383e-05
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.9916e-06 - val_loss: 2.3688e-05
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.8206e-06 - val_loss: 2.2702e-05
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.7972e-06 - val_loss: 2.2364e-05
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.6847e-06 - val_loss: 2.1448e-05
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.6170e-06 - val_loss: 2.0995e-05
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.5656e-06 - val_loss: 2.0503e-05
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.4729e-06 - val_loss: 2.0030e-05
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.4120e-06 - val_loss: 1.9656e-05
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.3454e-06 - val_loss: 1.8984e-05
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.3039e-06 - val_loss: 1.8770e-05
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.2362e-06 - val_loss: 1.8369e-05
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.2120e-06 - val_loss: 1.7933e-05
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.1542e-06 - val_loss: 1.7660e-05
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.1233e-06 - val_loss: 1.7354e-05
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.0760e-06 - val_loss: 1.7189e-05
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.0444e-06 - val_loss: 1.6842e-05
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.9857e-06 - val_loss: 1.6441e-05
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.9714e-06 - val_loss: 1.6329e-05
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.9319e-06 - val_loss: 1.6113e-05
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.9204e-06 - val_loss: 1.5766e-05
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.8767e-06 - val_loss: 1.5570e-05
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.8786e-06 - val_loss: 1.5270e-05
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.8285e-06 - val_loss: 1.5220e-05
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.8144e-06 - val_loss: 1.5159e-05
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.8119e-06 - val_loss: 1.4927e-05
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.7828e-06 - val_loss: 1.4834e-05
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.7468e-06 - val_loss: 1.4603e-05
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.7142e-06 - val_loss: 1.4380e-05
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.7098e-06 - val_loss: 1.4380e-05
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.6885e-06 - val_loss: 1.4064e-05
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.6791e-06 - val_loss: 1.3952e-05
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3.6538e-06 - val_loss: 1.3939e-05
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.6445e-06 - val_loss: 1.3755e-05
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.6179e-06 - val_loss: 1.3719e-05
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.6135e-06 - val_loss: 1.3533e-05
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.5881e-06 - val_loss: 1.3446e-05
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.5789e-06 - val_loss: 1.3448e-05
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.5699e-06 - val_loss: 1.3327e-05
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.5412e-06 - val_loss: 1.3311e-05
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.5397e-06 - val_loss: 1.3040e-05
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.5319e-06 - val_loss: 1.2862e-05
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.5351e-06 - val_loss: 1.2885e-05
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.5147e-06 - val_loss: 1.2772e-05
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.4910e-06 - val_loss: 1.2891e-05
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.4751e-06 - val_loss: 1.2677e-05
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.4677e-06 - val_loss: 1.2533e-05
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.4640e-06 - val_loss: 1.2473e-05
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4575e-06 - val_loss: 1.2516e-05
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4319e-06 - val_loss: 1.2352e-05
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4278e-06 - val_loss: 1.2223e-05
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4283e-06 - val_loss: 1.2174e-05
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.4177e-06 - val_loss: 1.2223e-05
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4078e-06 - val_loss: 1.2224e-05
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4085e-06 - val_loss: 1.2058e-05
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.4022e-06 - val_loss: 1.1972e-05
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.3730e-06 - val_loss: 1.1882e-05
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.3748e-06 - val_loss: 1.1985e-05
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.3590e-06 - val_loss: 1.1848e-05
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.3771e-06 - val_loss: 1.1918e-05
# Train MSE: 0.000003
# Validation MSE: 0.000012
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 8s 624us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 2s 622us/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Train R2: 0.999986
# Validation R2: 0.999949
# Model 2:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1158 - val_loss: 0.0043
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5.6535e-04 - val_loss: 0.0011
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9392e-04 - val_loss: 7.3175e-04
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1013e-04 - val_loss: 5.5378e-04
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.9521e-05 - val_loss: 4.5834e-04
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6.5938e-05 - val_loss: 4.0526e-04
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5.7760e-05 - val_loss: 3.6033e-04
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5.2633e-05 - val_loss: 3.2952e-04
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4.7457e-05 - val_loss: 3.0317e-04
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4.4288e-05 - val_loss: 2.8323e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4.0841e-05 - val_loss: 2.6462e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.7691e-05 - val_loss: 2.4397e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.5143e-05 - val_loss: 2.2660e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.2778e-05 - val_loss: 2.1565e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.0471e-05 - val_loss: 1.9909e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.8614e-05 - val_loss: 1.8837e-04
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.6919e-05 - val_loss: 1.8006e-04
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.5432e-05 - val_loss: 1.6968e-04
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.4013e-05 - val_loss: 1.6120e-04
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.2610e-05 - val_loss: 1.5017e-04
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.1566e-05 - val_loss: 1.4445e-04
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.0822e-05 - val_loss: 1.3715e-04
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9778e-05 - val_loss: 1.3265e-04
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9093e-05 - val_loss: 1.2635e-04
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.8372e-05 - val_loss: 1.2128e-04
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7705e-05 - val_loss: 1.1523e-04
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7098e-05 - val_loss: 1.1062e-04
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.6648e-05 - val_loss: 1.0646e-04
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.6076e-05 - val_loss: 1.0233e-04
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.5701e-05 - val_loss: 9.9390e-05
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.5307e-05 - val_loss: 9.6805e-05
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4969e-05 - val_loss: 9.3318e-05
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.4665e-05 - val_loss: 8.9535e-05
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.4254e-05 - val_loss: 8.7569e-05
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4075e-05 - val_loss: 8.5599e-05
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3765e-05 - val_loss: 8.2002e-05
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3576e-05 - val_loss: 8.0221e-05
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3323e-05 - val_loss: 7.8506e-05
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3189e-05 - val_loss: 7.6056e-05
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2947e-05 - val_loss: 7.4520e-05
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2789e-05 - val_loss: 7.2637e-05
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2674e-05 - val_loss: 7.0870e-05
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2560e-05 - val_loss: 6.9452e-05
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.2360e-05 - val_loss: 6.7405e-05
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2309e-05 - val_loss: 6.6312e-05
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2139e-05 - val_loss: 6.5722e-05
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2061e-05 - val_loss: 6.4554e-05
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1936e-05 - val_loss: 6.2685e-05
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1761e-05 - val_loss: 6.1663e-05
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1689e-05 - val_loss: 6.0661e-05
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1568e-05 - val_loss: 5.9947e-05
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1557e-05 - val_loss: 5.8949e-05
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1427e-05 - val_loss: 5.7376e-05
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1403e-05 - val_loss: 5.7016e-05
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1294e-05 - val_loss: 5.5915e-05
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1312e-05 - val_loss: 5.5712e-05
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1208e-05 - val_loss: 5.4536e-05
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1115e-05 - val_loss: 5.3831e-05
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1060e-05 - val_loss: 5.3031e-05
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0986e-05 - val_loss: 5.2288e-05
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0926e-05 - val_loss: 5.1761e-05
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0932e-05 - val_loss: 5.1027e-05
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0857e-05 - val_loss: 5.0187e-05
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0744e-05 - val_loss: 4.9641e-05
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0793e-05 - val_loss: 4.9707e-05
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0772e-05 - val_loss: 4.8900e-05
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0659e-05 - val_loss: 4.8736e-05
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0646e-05 - val_loss: 4.8417e-05
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0574e-05 - val_loss: 4.7242e-05
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0565e-05 - val_loss: 4.6710e-05
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0509e-05 - val_loss: 4.6350e-05
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0502e-05 - val_loss: 4.6109e-05
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0416e-05 - val_loss: 4.5418e-05
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0409e-05 - val_loss: 4.4961e-05
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0392e-05 - val_loss: 4.5220e-05
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0376e-05 - val_loss: 4.4115e-05
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0334e-05 - val_loss: 4.3999e-05
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0288e-05 - val_loss: 4.3604e-05
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0242e-05 - val_loss: 4.3881e-05
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0240e-05 - val_loss: 4.2971e-05
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0202e-05 - val_loss: 4.2568e-05
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0160e-05 - val_loss: 4.2373e-05
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0149e-05 - val_loss: 4.2218e-05
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0118e-05 - val_loss: 4.1559e-05
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0062e-05 - val_loss: 4.1358e-05
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0060e-05 - val_loss: 4.0849e-05
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0011e-05 - val_loss: 4.0796e-05
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0035e-05 - val_loss: 4.0606e-05
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.9889e-06 - val_loss: 4.0401e-05
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.9627e-06 - val_loss: 4.0408e-05
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.9837e-06 - val_loss: 3.9655e-05
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.8919e-06 - val_loss: 3.9124e-05
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.8814e-06 - val_loss: 3.9066e-05
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.9339e-06 - val_loss: 3.9128e-05
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.8822e-06 - val_loss: 3.8616e-05
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.8170e-06 - val_loss: 3.8174e-05
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.8094e-06 - val_loss: 3.8083e-05
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.8400e-06 - val_loss: 3.7804e-05
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.7810e-06 - val_loss: 3.8203e-05
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.7816e-06 - val_loss: 3.7881e-05
# Train MSE: 0.000010
# Validation MSE: 0.000038
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 6s 472us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 2s 468us/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Train R2: 0.999961
# Validation R2: 0.999839
# Model 3:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1329 - val_loss: 0.0048
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.1554e-04 - val_loss: 8.1939e-04
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.8896e-04 - val_loss: 4.3960e-04
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0038e-04 - val_loss: 3.0422e-04
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.1786e-05 - val_loss: 2.4098e-04
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1138e-05 - val_loss: 2.0684e-04
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.6482e-05 - val_loss: 1.9044e-04
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.3450e-05 - val_loss: 1.7313e-04
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.1420e-05 - val_loss: 1.6305e-04
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.9938e-05 - val_loss: 1.5193e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.8395e-05 - val_loss: 1.4413e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.7219e-05 - val_loss: 1.4018e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.5470e-05 - val_loss: 1.3378e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.5012e-05 - val_loss: 1.2915e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.4102e-05 - val_loss: 1.2321e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.3086e-05 - val_loss: 1.1789e-04
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.2353e-05 - val_loss: 1.1498e-04
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.1663e-05 - val_loss: 1.1050e-04
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.1084e-05 - val_loss: 1.0878e-04
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.0445e-05 - val_loss: 1.0476e-04
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.9984e-05 - val_loss: 1.0295e-04
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.9578e-05 - val_loss: 1.0005e-04
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.8845e-05 - val_loss: 9.6908e-05
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.8543e-05 - val_loss: 9.4327e-05
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.8322e-05 - val_loss: 9.3876e-05
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.7867e-05 - val_loss: 9.2196e-05
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.7412e-05 - val_loss: 9.0790e-05
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.7179e-05 - val_loss: 8.8687e-05
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.6854e-05 - val_loss: 8.7124e-05
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.6589e-05 - val_loss: 8.6870e-05
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.6268e-05 - val_loss: 8.4195e-05
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.6081e-05 - val_loss: 8.3119e-05
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.5961e-05 - val_loss: 8.1944e-05
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.5673e-05 - val_loss: 8.0491e-05
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.5559e-05 - val_loss: 8.0060e-05
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.5252e-05 - val_loss: 7.8841e-05
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.5175e-05 - val_loss: 7.8491e-05
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.5105e-05 - val_loss: 7.8915e-05
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.4757e-05 - val_loss: 7.7172e-05
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.4476e-05 - val_loss: 7.6819e-05
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.4454e-05 - val_loss: 7.5814e-05
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.4141e-05 - val_loss: 7.4898e-05
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.4036e-05 - val_loss: 7.4407e-05
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.3915e-05 - val_loss: 7.3732e-05
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.3904e-05 - val_loss: 7.3262e-05
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.3674e-05 - val_loss: 7.2437e-05
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3431e-05 - val_loss: 7.2227e-05
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3399e-05 - val_loss: 7.1913e-05
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3258e-05 - val_loss: 7.0752e-05
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.3027e-05 - val_loss: 7.0410e-05
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2933e-05 - val_loss: 7.0425e-05
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2666e-05 - val_loss: 6.9280e-05
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2656e-05 - val_loss: 6.9029e-05
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2355e-05 - val_loss: 6.9026e-05
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2436e-05 - val_loss: 6.7800e-05
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2389e-05 - val_loss: 6.7949e-05
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2237e-05 - val_loss: 6.7715e-05
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2035e-05 - val_loss: 6.7510e-05
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1982e-05 - val_loss: 6.7151e-05
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1885e-05 - val_loss: 6.6464e-05
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1724e-05 - val_loss: 6.6747e-05
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1541e-05 - val_loss: 6.6280e-05
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1430e-05 - val_loss: 6.6064e-05
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1343e-05 - val_loss: 6.4996e-05
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1213e-05 - val_loss: 6.6354e-05
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.1091e-05 - val_loss: 6.4807e-05
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1038e-05 - val_loss: 6.4464e-05
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1041e-05 - val_loss: 6.4129e-05
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0636e-05 - val_loss: 6.3988e-05
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0725e-05 - val_loss: 6.3957e-05
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0621e-05 - val_loss: 6.3605e-05
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0378e-05 - val_loss: 6.2724e-05
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0310e-05 - val_loss: 6.2561e-05
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0317e-05 - val_loss: 6.2859e-05
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0141e-05 - val_loss: 6.2569e-05
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0239e-05 - val_loss: 6.2651e-05
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0011e-05 - val_loss: 6.1869e-05
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.9909e-05 - val_loss: 6.1817e-05
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.9682e-05 - val_loss: 6.2042e-05
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9663e-05 - val_loss: 6.0784e-05
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9586e-05 - val_loss: 6.1120e-05
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.9492e-05 - val_loss: 6.0972e-05
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9468e-05 - val_loss: 6.0422e-05
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9219e-05 - val_loss: 6.0240e-05
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.9245e-05 - val_loss: 6.0152e-05
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9079e-05 - val_loss: 5.9899e-05
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.9062e-05 - val_loss: 5.9605e-05
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8814e-05 - val_loss: 5.9124e-05
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8948e-05 - val_loss: 5.9142e-05
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8691e-05 - val_loss: 5.8827e-05
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8568e-05 - val_loss: 5.8951e-05
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8622e-05 - val_loss: 5.8768e-05
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8397e-05 - val_loss: 5.9126e-05
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8338e-05 - val_loss: 5.8198e-05
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8385e-05 - val_loss: 5.8296e-05
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8402e-05 - val_loss: 5.8003e-05
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8093e-05 - val_loss: 5.7198e-05
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8113e-05 - val_loss: 5.7495e-05
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.7806e-05 - val_loss: 5.7458e-05
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7776e-05 - val_loss: 5.7479e-05
# Train MSE: 0.000028
# Validation MSE: 0.000057
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 6s 422us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 1s 403us/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Train R2: 0.999888
# Validation R2: 0.999755
# Model 4:
# Epoch 1/100
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1410 - val_loss: 0.0071
# Epoch 2/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 3/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.0431e-04 - val_loss: 9.2675e-04
# Epoch 4/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7500e-04 - val_loss: 6.9855e-04
# Epoch 5/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.2576e-04 - val_loss: 5.7109e-04
# Epoch 6/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.0133e-04 - val_loss: 5.1213e-04
# Epoch 7/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8552e-04 - val_loss: 4.7554e-04
# Epoch 8/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7336e-04 - val_loss: 4.4191e-04
# Epoch 9/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6502e-04 - val_loss: 4.2959e-04
# Epoch 10/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5790e-04 - val_loss: 4.0632e-04
# Epoch 11/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5254e-04 - val_loss: 3.9042e-04
# Epoch 12/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4446e-04 - val_loss: 3.7800e-04
# Epoch 13/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4050e-04 - val_loss: 3.5917e-04
# Epoch 14/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.3649e-04 - val_loss: 3.5114e-04
# Epoch 15/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.3304e-04 - val_loss: 3.4339e-04
# Epoch 16/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2814e-04 - val_loss: 3.2732e-04
# Epoch 17/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2522e-04 - val_loss: 3.1843e-04
# Epoch 18/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2219e-04 - val_loss: 3.1253e-04
# Epoch 19/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1933e-04 - val_loss: 2.9841e-04
# Epoch 20/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1727e-04 - val_loss: 2.9537e-04
# Epoch 21/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1480e-04 - val_loss: 2.8935e-04
# Epoch 22/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1256e-04 - val_loss: 2.8153e-04
# Epoch 23/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1054e-04 - val_loss: 2.7216e-04
# Epoch 24/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0868e-04 - val_loss: 2.6621e-04
# Epoch 25/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 966us/step - loss: 1.0651e-04 - val_loss: 2.6203e-04
# Epoch 26/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0535e-04 - val_loss: 2.5386e-04
# Epoch 27/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0357e-04 - val_loss: 2.4998e-04
# Epoch 28/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0168e-04 - val_loss: 2.4651e-04
# Epoch 29/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0018e-04 - val_loss: 2.4040e-04
# Epoch 30/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.9076e-05 - val_loss: 2.3611e-04
# Epoch 31/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.7434e-05 - val_loss: 2.2832e-04
# Epoch 32/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.6416e-05 - val_loss: 2.2542e-04
# Epoch 33/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.4897e-05 - val_loss: 2.1912e-04
# Epoch 34/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.3932e-05 - val_loss: 2.1459e-04
# Epoch 35/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.2975e-05 - val_loss: 2.1334e-04
# Epoch 36/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.1674e-05 - val_loss: 2.0896e-04
# Epoch 37/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.0584e-05 - val_loss: 2.0568e-04
# Epoch 38/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.9492e-05 - val_loss: 2.0125e-04
# Epoch 39/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.8662e-05 - val_loss: 2.0201e-04
# Epoch 40/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.7731e-05 - val_loss: 1.9578e-04
# Epoch 41/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.6492e-05 - val_loss: 1.9492e-04
# Epoch 42/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.5351e-05 - val_loss: 1.8809e-04
# Epoch 43/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.5147e-05 - val_loss: 1.8961e-04
# Epoch 44/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.3509e-05 - val_loss: 1.8390e-04
# Epoch 45/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.2999e-05 - val_loss: 1.8157e-04
# Epoch 46/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.2270e-05 - val_loss: 1.7899e-04
# Epoch 47/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.1664e-05 - val_loss: 1.7800e-04
# Epoch 48/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.0485e-05 - val_loss: 1.7668e-04
# Epoch 49/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.0037e-05 - val_loss: 1.7180e-04
# Epoch 50/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.9493e-05 - val_loss: 1.7177e-04
# Epoch 51/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.8376e-05 - val_loss: 1.6690e-04
# Epoch 52/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.7482e-05 - val_loss: 1.6587e-04
# Epoch 53/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.7115e-05 - val_loss: 1.6501e-04
# Epoch 54/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.6874e-05 - val_loss: 1.6312e-04
# Epoch 55/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.5793e-05 - val_loss: 1.6041e-04
# Epoch 56/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.5852e-05 - val_loss: 1.5861e-04
# Epoch 57/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.4809e-05 - val_loss: 1.5630e-04
# Epoch 58/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.3979e-05 - val_loss: 1.5439e-04
# Epoch 59/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.3829e-05 - val_loss: 1.5301e-04
# Epoch 60/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.3146e-05 - val_loss: 1.5117e-04
# Epoch 61/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.2617e-05 - val_loss: 1.5174e-04
# Epoch 62/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.1681e-05 - val_loss: 1.4984e-04
# Epoch 63/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.0924e-05 - val_loss: 1.4711e-04
# Epoch 64/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.0823e-05 - val_loss: 1.4473e-04
# Epoch 65/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.0085e-05 - val_loss: 1.4213e-04
# Epoch 66/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.9466e-05 - val_loss: 1.4457e-04
# Epoch 67/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.8909e-05 - val_loss: 1.4132e-04
# Epoch 68/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.8587e-05 - val_loss: 1.3993e-04
# Epoch 69/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.8100e-05 - val_loss: 1.3827e-04
# Epoch 70/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.7468e-05 - val_loss: 1.3712e-04
# Epoch 71/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.7214e-05 - val_loss: 1.3779e-04
# Epoch 72/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.6490e-05 - val_loss: 1.3570e-04
# Epoch 73/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.6078e-05 - val_loss: 1.3250e-04
# Epoch 74/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.5745e-05 - val_loss: 1.3202e-04
# Epoch 75/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.4997e-05 - val_loss: 1.3076e-04
# Epoch 76/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.4605e-05 - val_loss: 1.3121e-04
# Epoch 77/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.4479e-05 - val_loss: 1.2940e-04
# Epoch 78/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.3750e-05 - val_loss: 1.2836e-04
# Epoch 79/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.3207e-05 - val_loss: 1.2685e-04
# Epoch 80/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.3227e-05 - val_loss: 1.2671e-04
# Epoch 81/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.2655e-05 - val_loss: 1.2494e-04
# Epoch 82/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.2145e-05 - val_loss: 1.2514e-04
# Epoch 83/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.2114e-05 - val_loss: 1.2226e-04
# Epoch 84/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.1757e-05 - val_loss: 1.2257e-04
# Epoch 85/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0898e-05 - val_loss: 1.2107e-04
# Epoch 86/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0683e-05 - val_loss: 1.2060e-04
# Epoch 87/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0271e-05 - val_loss: 1.2164e-04
# Epoch 88/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.9987e-05 - val_loss: 1.1992e-04
# Epoch 89/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.9483e-05 - val_loss: 1.1832e-04
# Epoch 90/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.8832e-05 - val_loss: 1.1657e-04
# Epoch 91/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.8483e-05 - val_loss: 1.1607e-04
# Epoch 92/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.8478e-05 - val_loss: 1.1568e-04
# Epoch 93/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.7871e-05 - val_loss: 1.1457e-04
# Epoch 94/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.7585e-05 - val_loss: 1.1321e-04
# Epoch 95/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.7505e-05 - val_loss: 1.1285e-04
# Epoch 96/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.7317e-05 - val_loss: 1.1265e-04
# Epoch 97/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.6751e-05 - val_loss: 1.1230e-04
# Epoch 98/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.6393e-05 - val_loss: 1.1142e-04
# Epoch 99/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.6269e-05 - val_loss: 1.0966e-04
# Epoch 100/100
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.6007e-05 - val_loss: 1.0947e-04
# Train MSE: 0.000056
# Validation MSE: 0.000109
# 13456/13456 ━━━━━━━━━━━━━━━━━━━━ 6s 407us/step
# 3364/3364 ━━━━━━━━━━━━━━━━━━━━ 1s 401us/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Train R2: 0.999775
# Validation R2: 0.999534

# %% [markdown]
# ## Performance Metrics

# %%
from tabulate import tabulate

tr_mse = [float(el) for el in tr_mse]
vl_mse = [float(el) for el in vl_mse]
tr_r2 = [float(el) for el in tr_r2]
vl_r2 = [float(el) for el in vl_r2]

res = []
model_info = [1,2,3,4]
nodes = [256,128,64,32]

for i in range(len(model_info)):
  el = []
  el.append(model_info[i])
  el.append(nodes[i])
  el.append(tr_mse[i]*100)
  el.append(vl_mse[i]*100)
  el.append(tr_r2[i]*100)
  el.append(vl_r2[i]*100)
  res.append(el)
cols = ["Model","Nodes in Hidden Layer","Train MSE","Validation MSE","Train R2","Validation R2"]

print(tabulate(res, headers=cols, tablefmt="grid", colalign=("center", "center", "center", "center", "center", "center")))
# Out:
# +---------+-------------------------+-------------+------------------+------------+-----------------+
# |  Model  |  Nodes in Hidden Layer  |  Train MSE  |  Validation MSE  |  Train R2  |  Validation R2  |
# +=========+=========================+=============+==================+============+=================+
# |    1    |           256           |   0.0003    |      0.0012      |  99.9986   |     99.9949     |
# +---------+-------------------------+-------------+------------------+------------+-----------------+
# |    2    |           128           |    0.001    |      0.0038      |  99.9961   |     99.9839     |
# +---------+-------------------------+-------------+------------------+------------+-----------------+
# |    3    |           64            |   0.0028    |      0.0057      |  99.9888   |     99.9755     |
# +---------+-------------------------+-------------+------------------+------------+-----------------+
# |    4    |           32            |   0.0056    |      0.0109      |  99.9775   |     99.9534     |
# +---------+-------------------------+-------------+------------------+------------+-----------------+

# %% [markdown]
# After the analysing the performance metrics, the optimal number of nodes was found to be **256** as it had the least MSE and highest R2 score.

# %%
from keras import models
path = "LSTM_SoC_Updated81.h5"
opt_model = models.load_model(path)
opt_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 256)            │       267,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 267,523 (1.02 MB)
#  Trainable params: 267,521 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ## Model Testing

# %%
def plot_predictions(test, predicted):
    plt.figure(figsize=(8.5,4.5))
    plt.grid(True,linewidth=1,color='black',alpha=1)
    plt.plot(test, color="lime", label="Actual SoC",linewidth=2.75, linestyle='dashed')
    plt.plot(predicted, color="red", label="Predicted SoC",linewidth=2.75, linestyle='dotted')
    
    plt.ylabel("SoC [%]",color='black',fontsize=14)
    plt.xlabel("Time [s]",color='black',fontsize=14)
    plt.xlim(0,len(test)+100)
    plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.legend(fontsize=14)
    plt.show()

def return_mse(test, predicted):
    mse = mean_squared_error(test, predicted)
    print("Test MSE: {:.6f}.".format(mse))
def return_r2(test, predicted):
    r2 = r2_score(test, predicted)
    print("Test R2 {:.6f}.".format(r2))

# %%
attr = ['Battery Voltage [V]','Battery Current [A]','Battery Temperature [C]','SoC [%]']

# %% [markdown]
# ### Test Datasets

# %%
df_tst1 = pd.read_csv('TripA09.csv')
df_tst1 = df_tst1.fillna(method = 'bfill')
df_tst1 = df_tst1[:].loc[:,attr]
actual_soc1 = df_tst1.loc[:,"SoC [%]"].values
act_soc1 = df_tst1.loc[:,"SoC [%]"].values

inputs = df_tst1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mse1))
r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(r2_1))
# Out:
# 172/574 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\4231373930.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst1 = df_tst1.fillna(method = 'bfill')
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# Test MSE: 0.000150.
# Test R2 0.999953.

# %%
df_tst2 = pd.read_csv('TripA17.csv')
df_tst2 = df_tst2.fillna(method = 'bfill')
df_tst2 = df_tst2[:].loc[:,attr]
actual_soc2 = df_tst2.loc[:,"SoC [%]"].values
act_soc2 = df_tst2.loc[:,"SoC [%]"].values

inputs = df_tst2.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc2.reshape(-1,1))
X_test2, y_test2 = split_sequence(inputs, n_steps)
X_test2 = X_test2.reshape(X_test2.shape[0], X_test2.shape[1], features)

predicted_soc2 = opt_model.predict(X_test2)
predicted_soc2 = sc2.inverse_transform(predicted_soc2)

plot_predictions(actual_soc2,predicted_soc2)
mse2 = mean_squared_error(actual_soc2[0:inputs.shape[0]-1],predicted_soc2)
print("Test MSE: {:.6f}.".format(mse2))
r2_2 = r2_score(actual_soc2[0:inputs.shape[0]-1],predicted_soc2)
print("Test R2 {:.6f}.".format(r2_2))
# Out:
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\2488056845.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst2 = df_tst2.fillna(method = 'bfill')
# Test MSE: 0.000370.
# Test R2 0.999964.

# %%
df_tst3 = pd.read_csv('TripA23.csv')
df_tst3 = df_tst3.fillna(method = 'bfill')
df_tst3 = df_tst3[:].loc[:,attr]
actual_soc3 = df_tst3.loc[:,"SoC [%]"].values
act_soc3 = df_tst3.loc[:,"SoC [%]"].values

inputs = df_tst3.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc3.reshape(-1,1))
X_test3, y_test3 = split_sequence(inputs, n_steps)
X_test3 = X_test3.reshape(X_test3.shape[0], X_test3.shape[1], features)

predicted_soc3 = opt_model.predict(X_test3)
predicted_soc3 = sc2.inverse_transform(predicted_soc3)

plot_predictions(actual_soc3,predicted_soc3)
mse3 = mean_squared_error(actual_soc3[0:inputs.shape[0]-1],predicted_soc3)
print("Test MSE: {:.6f}.".format(mse3))
r2_3 = r2_score(actual_soc3[0:inputs.shape[0]-1],predicted_soc3)
print("Test R2 {:.6f}.".format(r2_3))
# Out:
# 194/326 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\885310300.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst3 = df_tst3.fillna(method = 'bfill')
# 326/326 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# Test MSE: 0.000118.
# Test R2 0.999948.

# %%
df_tst4 = pd.read_csv('TripA30.csv')
df_tst4 = df_tst4.fillna(method = 'bfill')
df_tst4 = df_tst4[:].loc[:,attr]
actual_soc4 = df_tst4.loc[:,"SoC [%]"].values
act_soc4 = df_tst4.loc[:,"SoC [%]"].values

inputs = df_tst4.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc4.reshape(-1,1))
X_test4, y_test4 = split_sequence(inputs, n_steps)
X_test4 = X_test4.reshape(X_test4.shape[0], X_test4.shape[1], features)

predicted_soc4 = opt_model.predict(X_test4)
predicted_soc4 = sc2.inverse_transform(predicted_soc4)

plot_predictions(actual_soc4,predicted_soc4)
mse4 = mean_squared_error(actual_soc4[0:inputs.shape[0]-1],predicted_soc4)
print("Test MSE: {:.6f}.".format(mse4))
r2_4 = r2_score(actual_soc4[0:inputs.shape[0]-1],predicted_soc4)
print("Test R2 {:.6f}.".format(r2_4))
# Out:
# 280/437 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\923861088.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst4 = df_tst4.fillna(method = 'bfill')
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# Test MSE: 0.000077.
# Test R2 0.999956.

# %%
df_tst5 = pd.read_csv('TripB02.csv')
df_tst5 = df_tst5.fillna(method = 'bfill')
df_tst5 = df_tst5[:].loc[:,attr]
actual_soc5 = df_tst5.loc[:,"SoC [%]"].values
act_soc5 = df_tst5.loc[:,"SoC [%]"].values

inputs = df_tst5.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc5.reshape(-1,1))
X_test5, y_test5 = split_sequence(inputs, n_steps)
X_test5 = X_test5.reshape(X_test5.shape[0], X_test5.shape[1], features)

predicted_soc5 = opt_model.predict(X_test5)
predicted_soc5 = sc2.inverse_transform(predicted_soc5)

plot_predictions(actual_soc5,predicted_soc5)
mse5 = mean_squared_error(actual_soc5[0:inputs.shape[0]-1],predicted_soc5)
print("Test MSE: {:.6f}.".format(mse5))
r2_5 = r2_score(actual_soc5[0:inputs.shape[0]-1],predicted_soc5)
print("Test R2 {:.6f}.".format(r2_5))
# Out:
# 173/504 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\195861478.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst5 = df_tst5.fillna(method = 'bfill')
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# Test MSE: 0.000569.
# Test R2 0.999968.

# %%
df_tst6 = pd.read_csv('TripB11.csv')
df_tst6 = df_tst6.fillna(method = 'bfill')
df_tst6 = df_tst6[:].loc[:,attr]
actual_soc6 = df_tst6.loc[:,"SoC [%]"].values
act_soc6 = df_tst6.loc[:,"SoC [%]"].values

inputs = df_tst6.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc6.reshape(-1,1))
X_test6, y_test6 = split_sequence(inputs, n_steps)
X_test6 = X_test6.reshape(X_test6.shape[0], X_test6.shape[1], features)

predicted_soc6 = opt_model.predict(X_test6)
predicted_soc6 = sc2.inverse_transform(predicted_soc6)

plot_predictions(actual_soc6,predicted_soc6)
mse6 = mean_squared_error(actual_soc6[0:inputs.shape[0]-1],predicted_soc6)
print("Test MSE: {:.6f}.".format(mse6))
r2_6 = r2_score(actual_soc6[0:inputs.shape[0]-1],predicted_soc6)
print("Test R2 {:.6f}.".format(r2_6))
# Out:
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\327712705.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst6 = df_tst6.fillna(method = 'bfill')
# Test MSE: 0.000331.
# Test R2 0.999960.

# %%
df_tst7 = pd.read_csv('TripB19.csv')
df_tst7 = df_tst7[:].loc[:,attr]
df_tst7 = df_tst7.fillna(method = 'bfill')
actual_soc7 = df_tst7.loc[:,"SoC [%]"].values
act_soc7 = df_tst7.loc[:,"SoC [%]"].values

inputs = df_tst7.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc7.reshape(-1,1))
X_test7, y_test7 = split_sequence(inputs, n_steps)
X_test7 = X_test7.reshape(X_test7.shape[0], X_test7.shape[1], features)

predicted_soc7 = opt_model.predict(X_test7)
predicted_soc7 = sc2.inverse_transform(predicted_soc7)

plot_predictions(actual_soc7,predicted_soc7)
mse7 = mean_squared_error(actual_soc7[0:inputs.shape[0]-1],predicted_soc7)
print("Test MSE: {:.6f}.".format(mse7))
r2_7 = r2_score(actual_soc7[0:inputs.shape[0]-1],predicted_soc7)
print("Test R2 {:.6f}.".format(r2_7))
# Out:
# 264/373 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\4284390979.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst7 = df_tst7.fillna(method = 'bfill')
# 373/373 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# Test MSE: 0.000885.
# Test R2 0.999966.

# %%
df_tst8 = pd.read_csv('TripB36.csv')
df_tst8 = df_tst8[:].loc[:,attr]
df_tst8 = df_tst8.fillna(method = 'bfill')
actual_soc8 = df_tst8.loc[:,"SoC [%]"].values
act_soc8 = df_tst8.loc[:,"SoC [%]"].values

inputs = df_tst8.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc8.reshape(-1,1))
X_test8, y_test8 = split_sequence(inputs, n_steps)
X_test8 = X_test8.reshape(X_test8.shape[0], X_test8.shape[1], features)

predicted_soc8 = opt_model.predict(X_test8)
predicted_soc8 = sc2.inverse_transform(predicted_soc8)

plot_predictions(actual_soc8,predicted_soc8)
mse8 = mean_squared_error(actual_soc8[0:inputs.shape[0]-1],predicted_soc8)
print("Test MSE: {:.6f}.".format(mse8))
r2_8 = r2_score(actual_soc8[0:inputs.shape[0]-1],predicted_soc8)
print("Test R2 {:.6f}.".format(r2_8))
# Out:
# 165/892 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\908716052.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst8 = df_tst8.fillna(method = 'bfill')
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 588us/step
# Test MSE: 0.002441.
# Test R2 0.999970.

# %%
df_tst9 = pd.read_csv('TripA01.csv')
df_tst9 = df_tst9.fillna(method = 'bfill')
df_tst9 = df_tst9[:].loc[:,attr]
actual_soc9 = df_tst9.loc[:,"SoC [%]"].values
act_soc9 = df_tst9.loc[:,"SoC [%]"].values

inputs = df_tst9.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc9.reshape(-1,1))
X_test9, y_test9 = split_sequence(inputs, n_steps)
X_test9 = X_test9.reshape(X_test9.shape[0], X_test9.shape[1], features)

predicted_soc9 = opt_model.predict(X_test9)
predicted_soc9 = sc2.inverse_transform(predicted_soc9)

plot_predictions(actual_soc9,predicted_soc9)
mse9 = mean_squared_error(actual_soc9[0:inputs.shape[0]-1],predicted_soc9)
print("Test MSE: {:.6f}.".format(mse9))
r2_9 = r2_score(actual_soc9[0:inputs.shape[0]-1],predicted_soc9)
print("Test R2 {:.6f}.".format(r2_9))
# Out:
# 257/316 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3412345231.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst9 = df_tst9.fillna(method = 'bfill')
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# Test MSE: 0.000174.
# Test R2 0.999928.

# %%
df_tst10 = pd.read_csv('TripB26.csv')
df_tst10 = df_tst10.fillna(method = 'bfill')
df_tst10 = df_tst10[:].loc[:,attr]
actual_soc10 = df_tst10.loc[:,"SoC [%]"].values
act_soc10 = df_tst10.loc[:,"SoC [%]"].values

inputs = df_tst10.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc10.reshape(-1,1))
X_test10, y_test10 = split_sequence(inputs, n_steps)
X_test10 = X_test10.reshape(X_test10.shape[0], X_test10.shape[1], features)

predicted_soc10 = opt_model.predict(X_test10)
predicted_soc10 = sc2.inverse_transform(predicted_soc10)

plot_predictions(actual_soc10,predicted_soc10)
mse10 = mean_squared_error(actual_soc10[0:inputs.shape[0]-1],predicted_soc10)
print("Test MSE: {:.6f}.".format(mse10))
r2_10 = r2_score(actual_soc10[0:inputs.shape[0]-1],predicted_soc10)
print("Test R2 {:.6f}.".format(r2_10))
# Out:
# 160/252 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3406158509.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst10 = df_tst10.fillna(method = 'bfill')
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# Test MSE: 0.000668.
# Test R2 0.999967.

# %%
df_tst11 = pd.read_csv('TripA14.csv')
df_tst11 = df_tst11.fillna(method = 'bfill')
df_tst11 = df_tst11[:].loc[:,attr]
actual_soc11 = df_tst11.loc[:,"SoC [%]"].values
act_soc11 = df_tst11.loc[:,"SoC [%]"].values

inputs = df_tst11.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc11.reshape(-1,1))
X_test11, y_test11 = split_sequence(inputs, n_steps)
X_test11 = X_test11.reshape(X_test11.shape[0], X_test11.shape[1], features)

predicted_soc11 = opt_model.predict(X_test11)
predicted_soc11 = sc2.inverse_transform(predicted_soc11)

plot_predictions(actual_soc11,predicted_soc11)
mse11 = mean_squared_error(actual_soc11[0:inputs.shape[0]-1],predicted_soc11)
print("Test MSE: {:.6f}.".format(mse11))
r2_11 = r2_score(actual_soc11[0:inputs.shape[0]-1],predicted_soc11)
print("Test R2 {:.6f}.".format(r2_11))
# Out:
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\1713404544.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst11 = df_tst11.fillna(method = 'bfill')
# Test MSE: 0.000047.
# Test R2 0.999942.

# %%
df_tst11 = pd.read_csv('TripA14.csv')
df_tst11 = df_tst11.fillna(method = 'bfill')
df_tst11 = df_tst11[:].loc[:,attr]
actual_soc11 = df_tst11.loc[:,"SoC [%]"].values
act_soc11 = df_tst11.loc[:,"SoC [%]"].values

inputs = df_tst11.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc11.reshape(-1,1))
X_test11, y_test11 = split_sequence(inputs, n_steps)
X_test11 = X_test11.reshape(X_test11.shape[0], X_test11.shape[1], features)

predicted_soc11 = opt_model.predict(X_test11)
predicted_soc11 = sc2.inverse_transform(predicted_soc11)

plot_predictions(actual_soc11,predicted_soc11)
mse11 = mean_squared_error(actual_soc11[0:inputs.shape[0]-1],predicted_soc11)
print("Test MSE: {:.6f}.".format(mse11))
r2_11 = r2_score(actual_soc11[0:inputs.shape[0]-1],predicted_soc11)
print("Test R2 {:.6f}.".format(r2_11))
# Out:
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\1713404544.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst11 = df_tst11.fillna(method = 'bfill')
# Test MSE: 0.000047.
# Test R2 0.999942.

# %%
df_tst12 = pd.read_csv('TripB06.csv')
df_tst12 = df_tst12.fillna(method = 'bfill')
df_tst12 = df_tst12[:].loc[:,attr]
actual_soc12 = df_tst12.loc[:,"SoC [%]"].values
act_soc12 = df_tst12.loc[:,"SoC [%]"].values

inputs = df_tst12.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc12.reshape(-1,1))
X_test12, y_test12 = split_sequence(inputs, n_steps)
X_test12 = X_test12.reshape(X_test12.shape[0], X_test12.shape[1], features)

predicted_soc12 = opt_model.predict(X_test12)
predicted_soc12 = sc2.inverse_transform(predicted_soc12)

plot_predictions(actual_soc12,predicted_soc12)
mse12 = mean_squared_error(actual_soc12[0:inputs.shape[0]-1],predicted_soc12)
print("Test MSE: {:.6f}.".format(mse12))
r2_12 = r2_score(actual_soc12[0:inputs.shape[0]-1],predicted_soc12)
print("Test R2 {:.6f}.".format(r2_12))
# Out:
# 247/423 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\2705842439.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_tst12 = df_tst12.fillna(method = 'bfill')
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# Test MSE: 0.000398.
# Test R2 0.999979.

# %%
from tabulate import tabulate

un_mse = [mse1,mse2,mse3,mse4,mse5,mse6,mse7,mse8,mse9,mse10,mse11,mse12]
un_r2 = [r2_1,r2_2,r2_3,r2_4,r2_5,r2_6,r2_7,r2_8,r2_9,r2_10,r2_11,r2_12]

res = []
trip_info = ["TripA09","TripA17","TripA23","TripA30","TripB02","TripB11","TripB19","TripB36","TripA01","TripB26","TripA14","TripB06"]
for i in range(len(trip_info)):
  el = []
  el.append(trip_info[i])
  el.append(round(float(un_mse[i])*100,4))
  el.append(round(float(un_r2[i])*100,4))
  res.append(el)
cols = ["Test Dataset Name","MSE","R2"]

print(tabulate(res, headers=cols, tablefmt="grid", colalign=("center", "center", "center")))
# Out:
# +---------------------+--------+---------+
# |  Test Dataset Name  |  MSE   |   R2    |
# +=====================+========+=========+
# |       TripA09       | 0.015  | 99.9953 |
# +---------------------+--------+---------+
# |       TripA17       | 0.037  | 99.9964 |
# +---------------------+--------+---------+
# |       TripA23       | 0.0118 | 99.9948 |
# +---------------------+--------+---------+
# |       TripA30       | 0.0077 | 99.9956 |
# +---------------------+--------+---------+
# |       TripB02       | 0.0569 | 99.9968 |
# +---------------------+--------+---------+
# |       TripB11       | 0.0331 | 99.996  |
# +---------------------+--------+---------+
# |       TripB19       | 0.0885 | 99.9966 |
# +---------------------+--------+---------+
# |       TripB36       | 0.2441 | 99.997  |
# +---------------------+--------+---------+
# |       TripA01       | 0.0174 | 99.9928 |
# +---------------------+--------+---------+
# |       TripB26       | 0.0668 | 99.9967 |
# +---------------------+--------+---------+
# |       TripA14       | 0.0047 | 99.9942 |
# +---------------------+--------+---------+
# |       TripB06       | 0.0398 | 99.9979 |
# +---------------------+--------+---------+

# %% [markdown]
# ### Results

# %%
un_mse100 = [el*100 for el in un_mse]
un_r2100 = [el*100 for el in un_r2]
avgmse = round(sum(un_mse100)/len(un_mse100),4)
avgr2 = round(sum(un_r2100)/len(un_r2100),4)
print("Average MSE (in %):",avgmse)
print("Average R2 (in %):",avgr2)
# Out:
# Average MSE (in %): 0.0519
# Average R2 (in %): 99.9958

# %% [markdown]
# ### Miscellaneous Testing

# %%
usm = []
urs = []

# %%
dft_1 = pd.read_csv('TripA05.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse4 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse4))
mis_r2_4 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_4))
# Out:
# 181/428 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3083456370.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# Test MSE: 0.000130.
# Test R2 0.999966.

# %%
dft_1 = pd.read_csv('TripA10.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse6 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse6))
mis_r2_6 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_6))
# Out:
# 171/443 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\1883886728.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# Test MSE: 0.000341.
# Test R2 0.999962.

# %%
dft_1 = pd.read_csv('TripA11.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse7 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse7))
mis_r2_7 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_7))
# Out:
# 254/446 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3814902231.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# Test MSE: 0.000514.
# Test R2 0.999971.

# %%
dft_1 = pd.read_csv('TripA13.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse8 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse8))
mis_r2_8 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_8))
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\720959683.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# Test MSE: 0.000036.
# Test R2 0.999931.

# %%
dft_1 = pd.read_csv('TripA18.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse11 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse11))
mis_r2_11 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_11))
# Out:
# 246/276 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\1771605260.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# Test MSE: 0.000354.
# Test R2 0.999957.

# %%
dft_1 = pd.read_csv('TripA19.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse12 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse12))
mis_r2_12 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_12))
# Out:
# 261/497 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3702527778.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 497/497 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# Test MSE: 0.000179.
# Test R2 0.999969.

# %%
dft_1 = pd.read_csv('TripA22.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse14 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse14))
mis_r2_14 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_14))
# Out:
# 278/575 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3802988045.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# Test MSE: 0.000487.
# Test R2 0.999966.

# %%
dft_1 = pd.read_csv('TripA26.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse16 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse16))
mis_r2_16 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_16))
# Out:
# 275/504 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3139477592.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# Test MSE: 0.000150.
# Test R2 0.999972.

# %%
dft_1 = pd.read_csv('TripA29.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse18 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse18))
mis_r2_18 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_18))
# Out:
# 232/419 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\4078843543.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# Test MSE: 0.000266.
# Test R2 0.999965.

# %%
dft_1 = pd.read_csv('TripA31.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse19 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse19))
mis_r2_19 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_19))
# Out:
# 251/371 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3244251458.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# Test MSE: 0.000334.
# Test R2 0.999968.

# %%
usm1 = []
urs1 = []
usm1 = [mis_mse4,mis_mse6,mis_mse7,mis_mse8,mis_mse11,mis_mse12,mis_mse14,mis_mse16,mis_mse18,mis_mse19]
urs1 = [mis_r2_4,mis_r2_6,mis_r2_7,mis_r2_8,mis_r2_11,mis_r2_12,mis_r2_14,mis_r2_16,mis_r2_18,mis_r2_19]

# %%
usm2 = []
urs2 = []

# %%
dft_1 = pd.read_csv('TripB04.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 178/924 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\4117885866.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 924/924 ━━━━━━━━━━━━━━━━━━━━ 1s 606us/step
# Test MSE: 0.005322.
# Test R2 0.999973.

# %%
dft_1 = pd.read_csv('TripB08.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 171/911 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3610025232.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 911/911 ━━━━━━━━━━━━━━━━━━━━ 1s 613us/step
# Test MSE: 0.001654.
# Test R2 0.999968.

# %%
dft_1 = pd.read_csv('TripB09.csv')
dft_1 = dft_1[:].loc[:,attr]
dft_1 = dft_1.dropna()
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 1s 618us/step
# Test MSE: 0.005603.
# Test R2 0.999969.

# %%
dft_1 = pd.read_csv('TripB12.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
#  174/1008 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\4232011739.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 1008/1008 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step
# Test MSE: 0.002507.
# Test R2 0.999906.

# %%
dft_1 = pd.read_csv('TripB14.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
#  164/1195 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\539066025.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 1195/1195 ━━━━━━━━━━━━━━━━━━━━ 1s 608us/step
# Test MSE: 0.008377.
# Test R2 0.999971.

# %%
dft_1 = pd.read_csv('TripB17.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 239/488 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\2333007882.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# Test MSE: 0.000607.
# Test R2 0.999973.

# %%
dft_1 = pd.read_csv('TripB18.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 253/347 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\2033045557.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# Test MSE: 0.000966.
# Test R2 0.999963.

# %%
dft_1 = pd.read_csv('TripB21.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 247/325 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3096730324.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# Test MSE: 0.000958.
# Test R2 0.999964.

# %%
dft_1 = pd.read_csv('TripB24.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 254/306 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\2725902585.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# Test MSE: 0.000233.
# Test R2 0.999964.

# %%
dft_1 = pd.read_csv('TripB29.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 155/303 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3732686610.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# Test MSE: 0.001319.
# Test R2 0.999959.

# %%
dft_1 = pd.read_csv('TripB32.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\2455074966.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# Test MSE: 0.000969.
# Test R2 0.999964.

# %%
dft_1 = pd.read_csv('TripB34.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\1184243548.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# Test MSE: 0.003993.
# Test R2 0.999898.

# %%
dft_1 = pd.read_csv('TripB35.csv')
dft1 = dft1.fillna(method = 'bfill')
dft_1 = dft_1[:].loc[:,attr]
actual_soc1 = dft_1.loc[:,"SoC [%]"].values
act_soc1 = dft_1.loc[:,"SoC [%]"].values

inputs = dft_1.values

sc1 = MinMaxScaler(feature_range=(-1, 1))
sc2 = MinMaxScaler(feature_range=(-1, 1))
inputs = sc1.fit_transform(inputs)
output = sc2.fit_transform(act_soc1.reshape(-1,1))
X_test1, y_test1 = split_sequence(inputs, n_steps)
X_test1 = X_test1.reshape(X_test1.shape[0], X_test1.shape[1], features)

predicted_soc1 = opt_model.predict(X_test1)
predicted_soc1 = sc2.inverse_transform(predicted_soc1)

plot_predictions(actual_soc1,predicted_soc1)
mis_mse1 = mean_squared_error(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test MSE: {:.6f}.".format(mis_mse1))
mis_r2_1 = r2_score(actual_soc1[0:inputs.shape[0]-1],predicted_soc1)
print("Test R2 {:.6f}.".format(mis_r2_1))
usm2.append(mis_mse1)
urs2.append(mis_r2_1)
# Out:
#   1/426 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
# C:\Users\moule\AppData\Local\Temp\ipykernel_3496\3389318454.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dft1 = dft1.fillna(method = 'bfill')
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# Test MSE: 0.000816.
# Test R2 0.999962.

# %%
usm = [y for x in [usm1, usm2] for y in x]
urs = [y for x in [urs1, urs2] for y in x]

# %%
from tabulate import tabulate

res = []
trip_info = ["TripA05","TripA10","TripA11","TripA13","TripA18","TripA19","TripA22","TripA26","TripA29","TripA31",
             "TripB04","TripB08","TripB09","TripB12","TripB14","TripB17","TripB18","TripB21","TripB24","TripB29","TripB32","TripB34",
             "TripB35"]
for i in range(len(trip_info)):
  el = []
  el.append(trip_info[i])
  el.append(round(usm[i]*100,4))
  el.append(round(urs[i]*100,4))
  res.append(el)
cols = ["Test Dataset Name","MSE","R2"]

print(tabulate(res, headers=cols, tablefmt="grid", colalign=("center", "center", "center")))
# Out:
# +---------------------+--------+---------+
# |  Test Dataset Name  |  MSE   |   R2    |
# +=====================+========+=========+
# |       TripA05       | 0.013  | 99.9966 |
# +---------------------+--------+---------+
# |       TripA10       | 0.0341 | 99.9962 |
# +---------------------+--------+---------+
# |       TripA11       | 0.0514 | 99.9971 |
# +---------------------+--------+---------+
# |       TripA13       | 0.0036 | 99.9931 |
# +---------------------+--------+---------+
# |       TripA18       | 0.0354 | 99.9957 |
# +---------------------+--------+---------+
# |       TripA19       | 0.0179 | 99.9969 |
# +---------------------+--------+---------+
# |       TripA22       | 0.0487 | 99.9966 |
# +---------------------+--------+---------+
# |       TripA26       | 0.015  | 99.9972 |
# +---------------------+--------+---------+
# |       TripA29       | 0.0266 | 99.9965 |
# +---------------------+--------+---------+
# |       TripA31       | 0.0334 | 99.9968 |
# +---------------------+--------+---------+
# |       TripB04       | 0.5322 | 99.9973 |
# +---------------------+--------+---------+
# |       TripB08       | 0.1654 | 99.9968 |
# +---------------------+--------+---------+
# |       TripB09       | 0.5603 | 99.9969 |
# +---------------------+--------+---------+
# |       TripB12       | 0.2507 | 99.9906 |
# +---------------------+--------+---------+
# |       TripB14       | 0.8377 | 99.9971 |
# +---------------------+--------+---------+
# |       TripB17       | 0.0607 | 99.9973 |
# +---------------------+--------+---------+
# |       TripB18       | 0.0966 | 99.9963 |
# +---------------------+--------+---------+
# |       TripB21       | 0.0958 | 99.9964 |
# +---------------------+--------+---------+
# |       TripB24       | 0.0233 | 99.9964 |
# +---------------------+--------+---------+
# |       TripB29       | 0.1319 | 99.9959 |
# +---------------------+--------+---------+
# |       TripB32       | 0.0969 | 99.9964 |
# +---------------------+--------+---------+
# |       TripB34       | 0.3993 | 99.9898 |
# +---------------------+--------+---------+
# |       TripB35       | 0.0816 | 99.9962 |
# +---------------------+--------+---------+

# %% [markdown]
# ### Results

# %%
usm100 = [el*100 for el in usm]
urs100 = [el*100 for el in urs]
avgmse = round(sum(usm100)/len(usm100),4)
avgr2 = round(sum(urs100)/len(urs100),4)
print("Average MSE (in %):",avgmse)
print("Average R2 (in %):",avgr2)
# Out:
# Average MSE (in %): 0.157
# Average R2 (in %): 99.9959

# %% [markdown]
# ***
