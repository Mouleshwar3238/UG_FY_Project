# %% [markdown]
# # Data Visualization for Category A Datasets

# %%
# Importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Reading the dataset
df1 = pd.read_csv("TripA04.csv")
df2 = pd.read_csv("TripA08.csv")
df3 = pd.read_csv("TripA12.csv")
df4 = pd.read_csv("TripA16.csv")
df5 = pd.read_csv("TripA20.csv")
df6 = pd.read_csv("TripA24.csv")
df7 = pd.read_csv("TripA28.csv")
df8 = pd.read_csv("TripA32.csv")

# %% [markdown]
# ## SoC versus Time

# %%
max_length = max(len(df) for df in [df1, df2, df3, df4, df5, df6, df7, df8])

time_data = []
soc_data = []

for i, df in enumerate([df1, df2, df3, df4, df5, df6, df7, df8]):
    soc = df['SoC [%]']
    time = df['Time [s]'] / 60

    time_data.append(time)
    soc_data.append(soc)
print(len(time_data))

plt.figure(figsize=(9,5))
plt.grid(True, linewidth=1, color='black', alpha=1)
lg = ['TripA04','TripA08','TripA12','TripA16','TripA20','TripA24','TripA28','TripA32']
colors = ['grey','green','orange','blue','red','brown','darkcyan','purple']

for i, (time, soc) in enumerate(zip(time_data, soc_data)):
    label = lg[i]
    plt.plot(time, soc, color=colors[i], linewidth=3, label=label)

plt.xlabel('Time [mins]', color='black', fontsize=14)
plt.ylabel('SoC [%]', color='black', fontsize=14)
plt.ylim((40,90))
plt.xlim((0,50))
plt.tick_params(axis='both', which='major', labelsize=14)

plt.legend(fontsize=14,ncol=1,loc="lower right",borderpad=0.35,handlelength=2,labelspacing=0.475,handletextpad=0.6)

plt.show()
# Out:
# 8

# %%
print(round(df1['SoC [%]'].describe(),4))
print(round(df2['SoC [%]'].describe(),4))
print(round(df3['SoC [%]'].describe(),4))
print(round(df4['SoC [%]'].describe(),4))
print(round(df5['SoC [%]'].describe(),4))
print(round(df6['SoC [%]'].describe(),4))
print(round(df7['SoC [%]'].describe(),4))
print(round(df8['SoC [%]'].describe(),4))
# Out:
# count    4124.0000
# mean       69.9496
# std         2.8933
# min        66.3000
# 25%        66.8000
# 50%        69.8350
# 75%        71.6700
# max        75.1000
# Name: SoC [%], dtype: float64
# count    28059.0000
# mean        80.9590
# std          3.2512
# min         76.1000
# 25%         78.0000
# 50%         80.5000
# 75%         84.7000
# max         86.6000
# Name: SoC [%], dtype: float64
# count    16384.0000
# mean        69.6265
# std          3.7594
# min         64.2000
# 25%         65.9000
# 50%         69.8000
# 75%         73.4000
# max         75.5000
# Name: SoC [%], dtype: float64
# count    19066.0000
# mean        55.0438
# std          5.5980
# min         46.8000
# 25%         49.5000
# 50%         55.7000
# 75%         60.4000
# max         63.0000
# Name: SoC [%], dtype: float64
# count    17196.0000
# mean        72.7392
# std          2.1911
# min         69.1000
# 25%         71.0000
# 50%         72.6000
# 75%         74.6000
# max         77.0000
# Name: SoC [%], dtype: float64
# count    5322.0000
# mean       76.6828
# std         2.5328
# min        74.2000
# 25%        74.5000
# 50%        75.8000
# 75%        78.3000
# max        81.9000
# Name: SoC [%], dtype: float64
# count    17436.0000
# mean        76.6719
# std          2.9679
# min         72.0000
# 25%         73.8000
# 50%         76.5000
# 75%         79.3000
# max         81.9000
# Name: SoC [%], dtype: float64
# count    16722.0000
# mean        72.2256
# std          9.6616
# min         59.5000
# 25%         60.9000
# 50%         72.7000
# 75%         79.9000
# max         86.5000
# Name: SoC [%], dtype: float64

# %%
print(round(df1['SoC [%]'].var(),4))
print(round(df2['SoC [%]'].var(),4))
print(round(df3['SoC [%]'].var(),4))
print(round(df4['SoC [%]'].var(),4))
print(round(df5['SoC [%]'].var(),4))
print(round(df6['SoC [%]'].var(),4))
print(round(df7['SoC [%]'].var(),4))
print(round(df8['SoC [%]'].var(),4))
# Out:
# 8.3709
# 10.5706
# 14.1329
# 31.3376
# 4.801
# 6.4149
# 8.8084
# 93.3471

# %% [markdown]
# ## Voltage versus Time

# %%
max_length = max(len(df) for df in [df1, df2, df3, df4, df5, df6, df7, df8])

time_data = []
voltage_data = []


for i, df in enumerate([df1, df2, df3, df4, df5, df6, df7, df8]):
    voltage = df['Battery Voltage [V]']
    time = df['Time [s]'] / 60

    time_data.append(time)
    voltage_data.append(voltage)
print(len(time_data))

plt.figure(figsize=(9,5))
plt.grid(True, linewidth=1, color='black', alpha=1)
lg = ['TripA04','TripA08','TripA12','TripA16','TripA20','TripA24','TripA28','TripA32']
colors = ['grey','green','orange','blue','red','brown','darkcyan','purple']

for i, (time, voltage) in enumerate(zip(time_data, voltage_data)):
    label = lg[i]
    plt.plot(time, voltage, color=colors[i], linewidth=2, label=label)

plt.xlabel('Time [mins]', color='black', fontsize=14)
plt.ylabel('Voltage [V]', color='black', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=14)

plt.legend(fontsize=14,ncol=1,loc="lower right",borderpad=0.35,handlelength=2,labelspacing=0.475,handletextpad=0.6)

plt.show()
# Out:
# 8

# %%
print(round(df1['Battery Voltage [V]'].describe(),4))
print(round(df2['Battery Voltage [V]'].describe(),4))
print(round(df3['Battery Voltage [V]'].describe(),4))
print(round(df4['Battery Voltage [V]'].describe(),4))
print(round(df5['Battery Voltage [V]'].describe(),4))
print(round(df6['Battery Voltage [V]'].describe(),4))
print(round(df7['Battery Voltage [V]'].describe(),4))
print(round(df8['Battery Voltage [V]'].describe(),4))
# Out:
# count    4124.0000
# mean      377.7679
# std         6.3936
# min       357.8000
# 25%       374.1800
# 50%       378.3300
# 75%       382.3825
# max       390.5900
# Name: Battery Voltage [V], dtype: float64
# count    28059.0000
# mean       388.3655
# std          2.5565
# min        369.2100
# 25%        387.2600
# 50%        388.5000
# 75%        390.6200
# max        394.5300
# Name: Battery Voltage [V], dtype: float64
# count    16384.0000
# mean       382.2902
# std          3.9836
# min        355.3100
# 25%        380.2100
# 50%        382.5000
# 75%        385.1825
# max        391.6600
# Name: Battery Voltage [V], dtype: float64
# count    19066.0000
# mean       372.1806
# std          4.6034
# min        359.2000
# 25%        368.8000
# 50%        371.0300
# 75%        375.1300
# max        385.2900
# Name: Battery Voltage [V], dtype: float64
# count    17196.0000
# mean       384.5787
# std          2.0141
# min        376.3000
# 25%        383.4000
# 50%        384.7300
# 75%        385.7400
# max        392.0900
# Name: Battery Voltage [V], dtype: float64
# count    5322.0000
# mean      380.9068
# std         6.4638
# min       357.1500
# 25%       377.4325
# 50%       381.9600
# 75%       385.2700
# max       394.3500
# Name: Battery Voltage [V], dtype: float64
# count    17436.0000
# mean       385.5036
# std          3.2690
# min        368.1760
# 25%        383.8277
# 50%        385.7644
# 75%        387.3821
# max        394.2135
# Name: Battery Voltage [V], dtype: float64
# count    16722.0000
# mean       378.4957
# std          8.2142
# min        353.1100
# 25%        372.6925
# 50%        377.1000
# 75%        385.4000
# max        394.5400
# Name: Battery Voltage [V], dtype: float64

# %%
print(round(df1['Battery Voltage [V]'].var(),4))
print(round(df2['Battery Voltage [V]'].var(),4))
print(round(df3['Battery Voltage [V]'].var(),4))
print(round(df4['Battery Voltage [V]'].var(),4))
print(round(df5['Battery Voltage [V]'].var(),4))
print(round(df6['Battery Voltage [V]'].var(),4))
print(round(df7['Battery Voltage [V]'].var(),4))
print(round(df8['Battery Voltage [V]'].var(),4))
# Out:
# 40.8776
# 6.5359
# 15.8688
# 21.1914
# 4.0566
# 41.7801
# 10.6862
# 67.4736

# %% [markdown]
# ## Current versus Time

# %%
max_length = max(len(df) for df in [df1, df2, df3, df4, df5, df6, df7, df8])

time_data = []
current_data = []

for i, df in enumerate([df1, df2, df3, df4, df5, df6, df7, df8]):
    current = df['Battery Current [A]']
    time = df['Time [s]'] / 60

    time_data.append(time)
    current_data.append(current)
print(len(time_data))

plt.figure(figsize=(9,5))
plt.grid(True, linewidth=1, color='black', alpha=1)
lg = ['TripA04','TripA08','TripA12','TripA16','TripA20','TripA24','TripA28','TripA32']
colors = ['grey','green','orange','blue','red','brown','darkcyan','purple']

for i, (time, current) in enumerate(zip(time_data, current_data)):
    label = lg[i]
    plt.plot(time, current, color=colors[i], linewidth=2, label=label)

plt.xlabel('Time [mins]', color='black', fontsize=14)
plt.ylabel('Current [A]', color='black', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=14)

plt.legend(fontsize=14,ncol=2,loc="lower right",borderpad=0.3,handlelength=1.5,labelspacing=0.45,handletextpad=0.5,columnspacing=1.5)

plt.show()
# Out:
# 8

# %%
print(round(df1['Battery Current [A]'].describe(),4))
print(round(df2['Battery Current [A]'].describe(),4))
print(round(df3['Battery Current [A]'].describe(),4))
print(round(df4['Battery Current [A]'].describe(),4))
print(round(df5['Battery Current [A]'].describe(),4))
print(round(df6['Battery Current [A]'].describe(),4))
print(round(df7['Battery Current [A]'].describe(),4))
print(round(df8['Battery Current [A]'].describe(),4))
# Out:
# count    4124.0000
# mean      -45.0568
# std        75.3271
# min      -357.0200
# 25%       -73.7050
# 50%       -19.6450
# 75%        -2.7000
# max       136.0100
# Name: Battery Current [A], dtype: float64
# count    28059.0000
# mean        -8.2505
# std         29.3413
# min       -262.0600
# 25%        -11.6500
# 50%         -3.1000
# 75%         -1.8500
# max        101.5600
# Name: Battery Current [A], dtype: float64
# count    16384.0000
# mean       -15.2048
# std         45.5738
# min       -395.1800
# 25%        -25.5125
# 50%         -8.8200
# 75%         -1.8900
# max        143.5300
# Name: Battery Current [A], dtype: float64
# count    19066.0000
# mean       -18.8512
# std         24.0418
# min       -135.0900
# 25%        -32.3000
# 50%        -15.8900
# 75%         -3.2600
# max        133.8800
# Name: Battery Current [A], dtype: float64
# count    17196.0000
# mean       -10.2091
# std         17.3914
# min        -84.9400
# 25%        -18.2225
# 50%         -6.8500
# 75%         -2.6000
# max         77.3600
# Name: Battery Current [A], dtype: float64
# count    5322.0000
# mean      -31.2080
# std        60.2743
# min      -289.6000
# 25%       -58.3525
# 50%       -15.7150
# 75%         0.6525
# max       126.4400
# Name: Battery Current [A], dtype: float64
# count    17436.0000
# mean       -12.6515
# std         30.0527
# min       -199.2709
# 25%        -23.1101
# 50%         -8.8076
# 75%         -1.5000
# max        105.3121
# Name: Battery Current [A], dtype: float64
# count    16722.0000
# mean       -35.8678
# std         61.7473
# min       -310.0400
# 25%        -59.4875
# 50%        -17.7700
# 75%         -2.5900
# max        137.5200
# Name: Battery Current [A], dtype: float64

# %%
print(round(df1['Battery Current [A]'].var(),4))
print(round(df2['Battery Current [A]'].var(),4))
print(round(df3['Battery Current [A]'].var(),4))
print(round(df4['Battery Current [A]'].var(),4))
print(round(df5['Battery Current [A]'].var(),4))
print(round(df6['Battery Current [A]'].var(),4))
print(round(df7['Battery Current [A]'].var(),4))
print(round(df8['Battery Current [A]'].var(),4))
# Out:
# 5674.1786
# 860.9135
# 2076.9753
# 578.006
# 302.4625
# 3632.9857
# 903.1668
# 3812.7244

# %% [markdown]
# ***
